# %% [markdown]
# #### Test simple cost model

# %%
# auto reload all modules
# %load_ext autoreload
# %autoreload 2

from simple_cost_model import *
from ssb_qgen_class import *

import time
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
qgen = QGEN()

example_query = qgen.generate_query(1)
print(example_query)
print(example_query.predicate_dict)
# Out:
# template id: 1, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_year = 1998
#                 AND lo_discount BETWEEN 3 AND 5
#                 AND lo_quantity < 25;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_year']}, order by: {}, group by: {}
# {'lineorder': [{'column': 'lo_orderdate', 'operator': 'eq', 'value': 'd_datekey', 'join': True}, {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}, {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}], 'dwdate': [{'column': 'd_year', 'operator': 'eq', 'value': 1998, 'join': False}]}

# %%
def actual_cost(query_object, indexes):
    candidate_indexes = list(indexes.values())
    conn = create_connection()
    # drop all existing secondary indexes 
    drop_all_indexes(conn)

    cost_wo_indexes, scan_costs = get_query_cost_estimate(conn, query_object.query_string, show_plan=False)
    print(f"Estimated cost without hypothetical indexes: {cost_wo_indexes}")
    print(f"Scan costs: {scan_costs}")

    # create hypothetical indexes for candidate indexes
    hypothetical_indexes = {}
    created_indexes = bulk_create_hypothetical_indexes(conn, candidate_indexes, return_size=True)
    for i in range(len(created_indexes)):
        hypothetical_indexes[created_indexes[i][0]] = (candidate_indexes[i], created_indexes[i][1]) 
        index_oid, index_size_mb = created_indexes[i]
        #print(f"Index {candidate_indexes[i].index_id} created with oid {index_oid} and size {index_size_mb} MB")

    # get the cost of the query with the hypothetical indexes
    print()
    cost_w_indexes, table_access_info, index_access_info, bitmap_heapscan_info = get_query_cost_estimate_hypo_indexes(conn, query_object.query_string, show_plan=False)
    print(f"\nEstimated cost with hypothetical indexes: {cost_w_indexes}")
    print(f"Speedup: {cost_wo_indexes/cost_w_indexes:.4f}")
    
    print(f"\nTable access info:")
    for table, info in table_access_info.items():
        print(f"\tTable --> {table}, Access info --> {info}")
    print(f"\nIndex access info:")
    for index_name, info in index_access_info.items():
        print(f"\tIndex --> {index_name}, Index scan type --> {info['scan_type']}, Cost --> {info['total_cost']}")
    print(f"\nBitmap heap scan info:")
    for index_name, info in bitmap_heapscan_info.items():
        print(f"\tIndex --> {index_name}, Bitmap Heapscan Cost --> {info['total_cost']}") 
        
    bulk_drop_hypothetical_indexes(conn)
    close_connection(conn)

# %%
# extract candidate indexes
candidate_indexes = extract_query_indexes(example_query, max_key_columns=3, include_cols=True, exclude_pk_indexes=True)
indexes = {index.index_id: index for index in candidate_indexes}

# %%
verbose = True

# Get the statistics for all tables in the SSB database
table_names = ["customer", "dwdate", "lineorder", "part", "supplier"]
stats = {}
estimated_rows = {}
for table_name in table_names:
    stats[table_name], estimated_rows[table_name] = get_table_stats(table_name)


# instantiate simple cost model
#model = SimpleCost(example_query, stats, estimated_rows, index_scan_cost_multiplier=1.5, verbose=verbose)
model = SimpleCost(stats, estimated_rows, index_scan_cost_multiplier=1.5)

# make prediction for example query
model.predict(example_query, indexes, verbose=verbose)
# Out:
# Tables and columns: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_extendedprice', 'lo_quantity'], 'dwdate': ['d_year', 'd_datekey']}
# Payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}
# Predicates:
#
# lineorder
# 	{'column': 'lo_orderdate', 'operator': 'eq', 'value': 'd_datekey', 'join': True}
# 	{'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}
# 	{'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}
#
# dwdate
# 	{'column': 'd_year', 'operator': 'eq', 'value': 1998, 'join': False}
# Predicates: {'lineorder': [0, 1, 2], 'dwdate': [3]}
# Join predicates: {'dwdate': [4]}
# Updated predicates: {'lineorder': [0, 1, 2], 'dwdate': [3, 4]}
#
# Table predicate columns for lineorder: ['lo_orderdate', 'lo_discount', 'lo_quantity']
# Relevant predicate columns for lineorder: {'lo_orderdate', 'lo_discount', 'lo_quantity'}
# Payload columns for lineorder: ['lo_extendedprice', 'lo_discount']
# Checking index:  ix_lineorder_lo_orderdate
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_d
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_e
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_d_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_discount
# Index scan possible!
# Checking index:  ixn_lineorder_lo_discount_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_quantity
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_d
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_e
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_d_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_orderdate_lo_discount
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_discount_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_orderdate_lo_quantity
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_quantity_lo_d
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_quantity_lo_e
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_quantity_lo_d_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_discount_lo_orderdate
# Index scan possible!
# Checking index:  ixn_lineorder_lo_discount_lo_orderdate_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_discount_lo_quantity
# Index scan possible!
# Checking index:  ixn_lineorder_lo_discount_lo_quantity_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_quantity_lo_orderdate
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_orderdate_lo_d
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_orderdate_lo_e
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_orderdate_lo_d_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_quantity_lo_discount
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_discount_lo_e
# Index scan possible!
# Checking index:  ix_lineorder_lo_orderdate_lo_discount_lo_quantity
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e
# Index scan possible!
# Index only scan possible!
# Checking index:  ix_lineorder_lo_orderdate_lo_quantity_lo_discount
# Index scan possible!
# Checking index:  ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e
# Index scan possible!
# Index only scan possible!
# Checking index:  ix_lineorder_lo_discount_lo_orderdate_lo_quantity
# Index scan possible!
# Checking index:  ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e
# Index scan possible!
# Index only scan possible!
# Checking index:  ix_lineorder_lo_discount_lo_quantity_lo_orderdate
# Index scan possible!
# Checking index:  ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e
# Index scan possible!
# Index only scan possible!
# Checking index:  ix_lineorder_lo_quantity_lo_orderdate_lo_discount
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e
# Index scan possible!
# Index only scan possible!
# Checking index:  ix_lineorder_lo_quantity_lo_discount_lo_orderdate
# Index scan possible!
# Checking index:  ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e
# Index scan possible!
# Index only scan possible!
#
# Table predicate columns for dwdate: ['d_year', 'd_datekey']
# Relevant predicate columns for dwdate: {'d_datekey', 'd_year'}
# Payload columns for dwdate: ['lo_extendedprice', 'lo_discount']
# Checking index:  ix_dwdate_d_year
# Index scan possible!
# Checking index:  ix_dwdate_d_datekey_d_year
# Index scan possible!
# Checking index:  ix_dwdate_d_year_d_datekey
# Index scan possible!
#
# Enumerated feasible access paths:
# Table: lineorder
#     {'scan_type': 'Sequential Scan'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_d'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_d_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_d'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_d_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_discount'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_quantity'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_d'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_d_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_orderdate'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_quantity'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_orderdate'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_d'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_d_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_discount'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_discount_lo_quantity'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e'}
#     {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_quantity_lo_discount'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e'}
#     {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_orderdate_lo_quantity'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}
#     {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_quantity_lo_orderdate'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e'}
#     {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_orderdate_lo_discount'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}
#     {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_discount_lo_orderdate'}
#     {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e'}
#     {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e'}
# Table: dwdate
#     {'scan_type': 'Sequential Scan'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_datekey_d_year'}
#     {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}
# Finding cheapest access paths for tables: dict_keys(['lineorder', 'dwdate'])
#
# Table: lineorder
# 	Computing cost for access path: {'scan_type': 'Sequential Scan'}
# 	Estimated number of pages for sequential scan: 759319
# 	Sequential scan cost: 759319.0
# 	Access path: {'scan_type': 'Sequential Scan'}, Cost: 759319.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate'}
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 1.0
# 	Estimated number of pages for index scan: 146665, Table pages: 759319
# 	Undiscounted scan cost --> 1358976.0, Discounted scan cost --> 1223078.4000000001, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate'}, Cost: 1223078.4000000001
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_d'}
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 1.0
# 	Estimated number of pages for index scan: 175912, Table pages: 759319
# 	Undiscounted scan cost --> 1402846.5, Discounted scan cost --> 1262561.85, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_d'}, Cost: 1262561.85
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_e'}
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 1.0
# 	Estimated number of pages for index scan: 190432, Table pages: 759319
# 	Undiscounted scan cost --> 1424626.5, Discounted scan cost --> 1282163.85, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_e'}, Cost: 1282163.85
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_d_lo_e'}
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 1.0
# 	Estimated number of pages for index scan: 219729, Table pages: 759319
# 	Undiscounted scan cost --> 1468572.0, Discounted scan cost --> 1321714.8, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_d_lo_e'}, Cost: 1321714.8
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.273600006
# 	Estimated number of pages for index scan: 40127, Table pages: 207749
# 	Undiscounted scan cost --> 371814.0, Discounted scan cost --> 371814.0, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount'}, Cost: 371814.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.273600006
# 	Estimated number of pages for index scan: 52102, Table pages: 207749
# 	Undiscounted scan cost --> 389776.5, Discounted scan cost --> 389776.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_e'}, Cost: 389776.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 69851, Table pages: 361638
# 	Undiscounted scan cost --> 647233.5, Discounted scan cost --> 647233.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity'}, Cost: 647233.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_d'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 83781, Table pages: 361638
# 	Undiscounted scan cost --> 668128.5, Discounted scan cost --> 668128.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_d'}, Cost: 668128.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 90696, Table pages: 361638
# 	Undiscounted scan cost --> 678501.0, Discounted scan cost --> 678501.0, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_e'}, Cost: 678501.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_d_lo_e'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 104649, Table pages: 361638
# 	Undiscounted scan cost --> 699430.5, Discounted scan cost --> 699430.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_d_lo_e'}, Cost: 699430.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_discount'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.273600006
# 	Estimated number of pages for index scan: 175912, Table pages: 207749
# 	Undiscounted scan cost --> 575491.5, Discounted scan cost --> 517942.35000000003, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_discount'}, Cost: 517942.35000000003
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.273600006
# 	Estimated number of pages for index scan: 219729, Table pages: 207749
# 	Undiscounted scan cost --> 641217.0, Discounted scan cost --> 577095.3, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_e'}, Cost: 577095.3
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_quantity'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 175912, Table pages: 361638
# 	Undiscounted scan cost --> 806325.0, Discounted scan cost --> 725692.5, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_quantity'}, Cost: 725692.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_d'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 205432, Table pages: 361638
# 	Undiscounted scan cost --> 850605.0, Discounted scan cost --> 765544.5, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_d'}, Cost: 765544.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 219729, Table pages: 361638
# 	Undiscounted scan cost --> 872050.5, Discounted scan cost --> 784845.4500000001, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_e'}, Cost: 784845.4500000001
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_d_lo_e'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 249942, Table pages: 361638
# 	Undiscounted scan cost --> 917370.0, Discounted scan cost --> 825633.0, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_d_lo_e'}, Cost: 825633.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_orderdate'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.273600006
# 	Estimated number of pages for index scan: 48129, Table pages: 207749
# 	Undiscounted scan cost --> 383817.0, Discounted scan cost --> 364626.14999999997, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_orderdate'}, Cost: 364626.14999999997
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.273600006
# 	Estimated number of pages for index scan: 60118, Table pages: 207749
# 	Undiscounted scan cost --> 401800.5, Discounted scan cost --> 381710.475, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_e'}, Cost: 381710.475
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_quantity'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 48129, Table pages: 98944
# 	Undiscounted scan cost --> 220609.5, Discounted scan cost --> 220609.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_quantity'}, Cost: 220609.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 60118, Table pages: 98944
# 	Undiscounted scan cost --> 238593.0, Discounted scan cost --> 238593.0, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_e'}, Cost: 238593.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_orderdate'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 83781, Table pages: 361638
# 	Undiscounted scan cost --> 668128.5, Discounted scan cost --> 634722.075, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_orderdate'}, Cost: 634722.075
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_d'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 97840, Table pages: 361638
# 	Undiscounted scan cost --> 689217.0, Discounted scan cost --> 654756.15, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_d'}, Cost: 654756.15
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_e'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 104649, Table pages: 361638
# 	Undiscounted scan cost --> 699430.5, Discounted scan cost --> 664458.975, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_e'}, Cost: 664458.975
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_d_lo_e'}
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.4762666669999999
# 	Estimated number of pages for index scan: 119039, Table pages: 361638
# 	Undiscounted scan cost --> 721015.5, Discounted scan cost --> 684964.725, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_d_lo_e'}, Cost: 684964.725
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_discount'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 83781, Table pages: 98944
# 	Undiscounted scan cost --> 274087.5, Discounted scan cost --> 274087.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_discount'}, Cost: 274087.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 104649, Table pages: 98944
# 	Undiscounted scan cost --> 305389.5, Discounted scan cost --> 305389.5, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_e'}, Cost: 305389.5
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_discount_lo_quantity'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 205432, Table pages: 98944
# 	Undiscounted scan cost --> 456564.0, Discounted scan cost --> 410907.60000000003, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_discount_lo_quantity'}, Cost: 410907.60000000003
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 249942, Table pages: 98944
# 	Undiscounted scan cost --> 523329.0, Discounted scan cost --> 470996.10000000003, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e'}, Cost: 470996.10000000003
#
# 	Computing cost for access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 249942, Table pages: 0
# 	Undiscounted scan cost --> 374913.0, Discounted scan cost --> 337421.7, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e'}, Cost: 337421.7
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_quantity_lo_discount'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 205432, Table pages: 98944
# 	Undiscounted scan cost --> 456564.0, Discounted scan cost --> 410907.60000000003, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_orderdate_lo_quantity_lo_discount'}, Cost: 410907.60000000003
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 249942, Table pages: 98944
# 	Undiscounted scan cost --> 523329.0, Discounted scan cost --> 470996.10000000003, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e'}, Cost: 470996.10000000003
#
# 	Computing cost for access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_orderdate, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 249942, Table pages: 0
# 	Undiscounted scan cost --> 374913.0, Discounted scan cost --> 337421.7, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e'}, Cost: 337421.7
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_orderdate_lo_quantity'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 56206, Table pages: 98944
# 	Undiscounted scan cost --> 232725.0, Discounted scan cost --> 221088.75, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_orderdate_lo_quantity'}, Cost: 221088.75
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 68384, Table pages: 98944
# 	Undiscounted scan cost --> 250992.0, Discounted scan cost --> 238442.4, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}, Cost: 238442.4
#
# 	Computing cost for access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 68384, Table pages: 0
# 	Undiscounted scan cost --> 102576.0, Discounted scan cost --> 97447.2, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}, Cost: 97447.2
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_quantity_lo_orderdate'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 56206, Table pages: 98944
# 	Undiscounted scan cost --> 232725.0, Discounted scan cost --> 221088.75, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_discount_lo_quantity_lo_orderdate'}, Cost: 221088.75
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 68384, Table pages: 98944
# 	Undiscounted scan cost --> 250992.0, Discounted scan cost --> 238442.4, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e'}, Cost: 238442.4
#
# 	Computing cost for access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_discount, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.273600006, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 68384, Table pages: 0
# 	Undiscounted scan cost --> 102576.0, Discounted scan cost --> 97447.2, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_quantity_lo_orderdate_lo_e'}, Cost: 97447.2
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_orderdate_lo_discount'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 97840, Table pages: 98944
# 	Undiscounted scan cost --> 295176.0, Discounted scan cost --> 280417.2, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_orderdate_lo_discount'}, Cost: 280417.2
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 119039, Table pages: 98944
# 	Undiscounted scan cost --> 326974.5, Discounted scan cost --> 310625.77499999997, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}, Cost: 310625.77499999997
#
# 	Computing cost for access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 119039, Table pages: 0
# 	Undiscounted scan cost --> 178558.5, Discounted scan cost --> 169630.57499999998, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}, Cost: 169630.57499999998
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_discount_lo_orderdate'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 97840, Table pages: 98944
# 	Undiscounted scan cost --> 295176.0, Discounted scan cost --> 280417.2, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_discount_lo_orderdate'}, Cost: 280417.2
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 119039, Table pages: 98944
# 	Undiscounted scan cost --> 326974.5, Discounted scan cost --> 310625.77499999997, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e'}, Cost: 310625.77499999997
#
# 	Computing cost for access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e'}
# 		Selectivity for predicate {'column': 'lo_discount', 'operator': 'range', 'value': (3, 5), 'join': False}: 0.273600006
# 		Selectivity for predicate {'column': 'lo_quantity', 'operator': '<', 'value': 25, 'join': False}: 0.4762666669999999
# 	Leading column: lo_quantity, Predicate columns: ['lo_orderdate', 'lo_discount', 'lo_quantity'], Join columns: ['lo_orderdate']
# 	Leading column selectivity: 0.4762666669999999, Combined selectivity: 0.13030656294879997
# 	Estimated number of pages for index scan: 119039, Table pages: 0
# 	Undiscounted scan cost --> 178558.5, Discounted scan cost --> 169630.57499999998, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_discount_lo_orderdate_lo_e'}, Cost: 169630.57499999998
#
# 	Cheapest access path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}, Cost: 97447.2
#
# Table: dwdate
# 	Computing cost for access path: {'scan_type': 'Sequential Scan'}
# 	Estimated number of pages for sequential scan: 38
# 	Sequential scan cost: 38.0
# 	Access path: {'scan_type': 'Sequential Scan'}, Cost: 38.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year'}
# 		Selectivity for predicate {'column': 'd_year', 'operator': 'eq', 'value': 1998, 'join': False}: 0.14241001
# 	Leading column: d_year, Predicate columns: ['d_year', 'd_datekey'], Join columns: ['d_datekey']
# 	Leading column selectivity: 0.14241001, Combined selectivity: 0.14241001
# 	Estimated number of pages for index scan: 1, Table pages: 5
# 	Undiscounted scan cost --> 9.0, Discounted scan cost --> 9.0, Discount factor --> 1.0
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year'}, Cost: 9.0
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_datekey_d_year'}
# 		Selectivity for predicate {'column': 'd_year', 'operator': 'eq', 'value': 1998, 'join': False}: 0.14241001
# 	Leading column: d_datekey, Predicate columns: ['d_year', 'd_datekey'], Join columns: ['d_datekey']
# 	Leading column selectivity: 1.0, Combined selectivity: 0.14241001
# 	Estimated number of pages for index scan: 7, Table pages: 5
# 	Undiscounted scan cost --> 18.0, Discounted scan cost --> 16.2, Discount factor --> 0.9
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_datekey_d_year'}, Cost: 16.2
#
# 	Computing cost for access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}
# 		Selectivity for predicate {'column': 'd_year', 'operator': 'eq', 'value': 1998, 'join': False}: 0.14241001
# 	Leading column: d_year, Predicate columns: ['d_year', 'd_datekey'], Join columns: ['d_datekey']
# 	Leading column selectivity: 0.14241001, Combined selectivity: 0.14241001
# 	Estimated number of pages for index scan: 1, Table pages: 5
# 	Undiscounted scan cost --> 9.0, Discounted scan cost --> 8.549999999999999, Discount factor --> 0.95
# 	Access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}, Cost: 8.549999999999999
#
# 	Cheapest access path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}, Cost: 8.549999999999999
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}, Cost: 97447.2
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}, Cost: 8.549999999999999
# (97455.75,
#  ['ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e',
#   'ix_dwdate_d_year_d_datekey'])

# %%
actual_cost(example_query, indexes)
# Out:
# Estimated cost without hypothetical indexes: 1972556.69
# Scan costs: {'Seq Scan': 1946433.73}
#
#
# Estimated cost with hypothetical indexes: 119311.26
# Speedup: 16.5329
#
# Table access info:
#
# Index access info:
# 	Index --> <13572>btree_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_, Index scan type --> Index Only Scan, Cost --> 279.96
# 	Index --> <13585>btree_dwdate_d_year_d_datekey, Index scan type --> Index Only Scan, Cost --> 14.4
#
# Bitmap heap scan info:

# %% [markdown]
# #### Compare predicted and actual access paths for all query templates

# %%
simple_model_time = 0.0
whatif_time = 0.0

for i in range(1, 15):
    query_object = qgen.generate_query(i)
    print(query_object)
    candidate_indexes = extract_query_indexes(query_object, max_key_columns=3, include_cols=True, exclude_pk_indexes=True)
    indexes = {index.index_id: index for index in candidate_indexes}
    t1 = time.time()
    # instantiate simple cost model
    #model = SimpleCost(example_query, stats, estimated_rows, index_scan_cost_multiplier=1.5, verbose=verbose)
    # predict the cost of the query
    cost, used = model.predict(query_object, indexes, verbose=False)
    t2 = time.time()
    simple_model_time += t2 - t1
    print(f"\nSimple model cost: {cost}")
    print(f"Predicted indexes used in the query plan: {used}")    
    print("\n")
    t1 = time.time()
    actual_cost(query_object, indexes)
    t2 = time.time()
    whatif_time += t2 - t1
    print("\n")

print(f"Simple model time: {simple_model_time}")
print(f"What-if time: {whatif_time}")
# Out:
# template id: 1, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_year = 1997
#                 AND lo_discount BETWEEN 5 AND 7
#                 AND lo_quantity < 25;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_year']}, order by: {}, group by: {}
#
# Simple model cost: 97324.65
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e', 'ix_dwdate_d_year_d_datekey']
#
#
# Estimated cost without hypothetical indexes: 1972536.97
# Scan costs: {'Seq Scan': 1946433.73}
#
#
# Estimated cost with hypothetical indexes: 119540.67
# Speedup: 16.5010
#
# Table access info:
#
# Index access info:
# 	Index --> <13572>btree_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_, Index scan type --> Index Only Scan, Cost --> 279.76
# 	Index --> <13585>btree_dwdate_d_year_d_datekey, Index scan type --> Index Only Scan, Cost --> 14.42
#
# Bitmap heap scan info:
#
#
# template id: 2, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_yearmonthnum = 199510
#                 AND lo_discount BETWEEN 1  AND 3
#                 AND lo_quantity BETWEEN 2 AND 11;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_yearmonthnum']}, order by: {}, group by: {}
#
# Simple model cost: 70748.40000000001
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e', 'ix_dwdate_d_yearmonthnum_d_datekey']
#
#
# Estimated cost without hypothetical indexes: 2105108.2
# Scan costs: {'Seq Scan': 2096399.27}
#
#
# Estimated cost with hypothetical indexes: 7071.9
# Speedup: 297.6722
#
# Table access info:
#
# Index access info:
# 	Index --> <13574>btree_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_, Index scan type --> Index Only Scan, Cost --> 208.19
# 	Index --> <13585>btree_dwdate_d_yearmonthnum_d_datekey, Index scan type --> Index Only Scan, Cost --> 4.57
#
# Bitmap heap scan info:
#
#
# template id: 3, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_weeknuminyear = 51
#                 AND d_year = 1992
#                 AND lo_discount BETWEEN 2 AND 4
#                 AND lo_quantity BETWEEN 40 AND 49;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_weeknuminyear']}, order by: {}, group by: {}
#
# Simple model cost: 71485.125
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e', 'ix_dwdate_d_weeknuminyear_d_datekey']
#
#
# Estimated cost without hypothetical indexes: 2105077.84
# Scan costs: {'Seq Scan': 2096405.6600000001}
#
#
# Estimated cost with hypothetical indexes: 1659.67
# Speedup: 1268.3713
#
# Table access info:
#
# Index access info:
# 	Index --> <13574>btree_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_, Index scan type --> Index Only Scan, Cost --> 209.85
# 	Index --> <13585>btree_dwdate_d_weeknuminyear_d_datekey, Index scan type --> Bitmap Index Scan, Cost --> 4.4
#
# Bitmap heap scan info:
# 	Index --> dwdate, Bitmap Heapscan Cost --> 50.32
#
#
# template id: 4, query:
#                 SELECT SUM(lo_revenue), d_year, p_brand
#                 FROM lineorder, dwdate, part, supplier
#                 WHERE lo_orderdate = d_datekey
#                 AND lo_partkey = p_partkey
#                 AND lo_suppkey = s_suppkey
#                 AND p_category = 'MFGR#41'
#                 AND s_region = 'MIDDLE EAST'
#                 GROUP BY d_year, p_brand
#                 ORDER BY d_year, p_brand;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'part': ['p_brand']}, predicates: {'lineorder': ['lo_orderdate', 'lo_partkey', 'lo_suppkey'], 'dwdate': ['d_year', 'd_datekey'], 'part': ['p_partkey', 'p_category', 'p_brand'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand']}, group by: {'dwdate': ['d_year'], 'part': ['p_brand']}
#
# Simple model cost: 304833.20924999996
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_orderdate_lo_partkey_lo_suppkey_lo_r', 'ixn_dwdate_d_datekey_d_ye', 'ixn_part_p_category_p_partkey_p_br', 'ix_supplier_s_region_s_suppkey']
#
#
# Estimated cost without hypothetical indexes: 1688318.53
# Scan costs: {'Seq Scan': 1518565.72}
#
#
# Estimated cost with hypothetical indexes: 228897.03
# Speedup: 7.3759
#
# Table access info:
# 	Table --> dwdate, Access info --> {'total_cost': 68.56, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
#
# Index access info:
# 	Index --> <13599>btree_supplier_s_region_s_suppkey, Index scan type --> Index Only Scan, Cost --> 139.51
# 	Index --> <13570>btree_lineorder_lo_partkey_lo_suppkey_lo_orderdate_lo_re, Index scan type --> Index Only Scan, Cost --> 5.7
# 	Index --> <13594>btree_part_p_category_p_brand_p_partkey, Index scan type --> Index Only Scan, Cost --> 1427.45
#
# Bitmap heap scan info:
#
#
# template id: 5, query:
#                 SELECT SUM(lo_revenue), d_year, p_brand
#                 FROM lineorder, dwdate, part, supplier
#                 WHERE lo_orderdate = d_datekey
#                 AND lo_partkey = p_partkey
#                 AND lo_suppkey = s_suppkey
#                 AND p_brand BETWEEN 'MFGR#3908' AND 'MFGR#3915'
#                 AND s_region = 'AMERICA'
#                 GROUP BY d_year, p_brand
#                 ORDER BY d_year, p_brand;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'part': ['p_brand']}, predicates: {'lineorder': ['lo_orderdate', 'lo_partkey', 'lo_suppkey'], 'dwdate': ['d_year', 'd_datekey'], 'part': ['p_partkey', 'p_category', 'p_brand'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand']}, group by: {'dwdate': ['d_year'], 'part': ['p_brand']}
#
# Simple model cost: 304669.33425
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_orderdate_lo_partkey_lo_suppkey_lo_r', 'ixn_dwdate_d_datekey_d_ye', 'ix_part_p_brand_p_partkey', 'ix_supplier_s_region_s_suppkey']
#
#
# Estimated cost without hypothetical indexes: 1686234.08
# Scan costs: {'Seq Scan': 1520018.72, 'Index Scan': 0.31}
#
#
# Estimated cost with hypothetical indexes: 6426.92
# Speedup: 262.3705
#
# Table access info:
# 	Table --> dwdate, Access info --> {'total_cost': 68.56, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
#
# Index access info:
# 	Index --> <13599>btree_supplier_s_region_s_suppkey, Index scan type --> Index Only Scan, Cost --> 139.82
# 	Index --> <13570>btree_lineorder_lo_partkey_lo_suppkey_lo_orderdate_lo_re, Index scan type --> Index Only Scan, Cost --> 5.9
# 	Index --> <13589>btree_part_p_brand_p_partkey, Index scan type --> Index Only Scan, Cost --> 39.99
#
# Bitmap heap scan info:
#
#
# template id: 6, query:
#                 SELECT SUM(lo_revenue), d_year, p_brand
#                 FROM lineorder, dwdate, part, supplier
#                 WHERE lo_orderdate = d_datekey
#                 AND lo_partkey = p_partkey
#                 AND lo_suppkey = s_suppkey
#                 AND p_brand = 'MFGR#1321'
#                 AND s_region = 'AMERICA'
#                 GROUP BY d_year, p_brand
#                 ORDER BY d_year, p_brand;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'part': ['p_brand']}, predicates: {'lineorder': ['lo_orderdate', 'lo_partkey', 'lo_suppkey'], 'dwdate': ['d_year', 'd_datekey'], 'part': ['p_partkey', 'p_category', 'p_brand'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand']}, group by: {'dwdate': ['d_year'], 'part': ['p_brand']}
#
# Simple model cost: 304669.33425
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_orderdate_lo_partkey_lo_suppkey_lo_r', 'ixn_dwdate_d_datekey_d_ye', 'ix_part_p_brand_p_partkey', 'ix_supplier_s_region_s_suppkey']
#
#
# Estimated cost without hypothetical indexes: 1684148.98
# Scan costs: {'Seq Scan': 1518018.72, 'Index Scan': 0.31}
#
#
# Estimated cost with hypothetical indexes: 6092.94
# Speedup: 276.4099
#
# Table access info:
# 	Table --> dwdate, Access info --> {'total_cost': 68.56, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
#
# Index access info:
# 	Index --> <13599>btree_supplier_s_region_s_suppkey, Index scan type --> Index Only Scan, Cost --> 139.82
# 	Index --> <13570>btree_lineorder_lo_partkey_lo_suppkey_lo_orderdate_lo_re, Index scan type --> Index Only Scan, Cost --> 5.9
# 	Index --> <13589>btree_part_p_brand_p_partkey, Index scan type --> Index Only Scan, Cost --> 37.96
#
# Bitmap heap scan info:
#
#
# template id: 7, query:
#                 SELECT c_nation, s_nation, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'AFRICA'
#                 AND s_region = 'AFRICA'
#                 AND d_year >= 1992 AND d_year <= 1997
#                 GROUP BY c_nation, s_nation, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_nation'], 'supplier': ['s_nation']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_region', 'c_nation'], 'supplier': ['s_suppkey', 's_region', 's_nation']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_nation'], 'supplier': ['s_nation'], 'dwdate': ['d_year']}
#
# Simple model cost: 304920.6592499999
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r', 'ix_dwdate_d_year_d_datekey', 'ixn_customer_c_region_c_custkey_c_na', 'ixn_supplier_s_region_s_suppkey_s_na']
#
#
# Estimated cost without hypothetical indexes: 1720182.19
# Scan costs: {'Seq Scan': 1505408.5}
#
#
# Estimated cost with hypothetical indexes: 599671.94
# Speedup: 2.8685
#
# Table access info:
#
# Index access info:
# 	Index --> <13577>btree_dwdate_d_year_d_datekey, Index scan type --> Index Only Scan, Cost --> 75.87
# 	Index --> <13594>btree_customer_c_region_c_nation_c_custkey, Index scan type --> Index Only Scan, Cost --> 2384.41
# 	Index --> <13570>btree_lineorder_lo_suppkey_lo_orderdate_lo_custkey_lo_re, Index scan type --> Index Only Scan, Cost --> 110.69
# 	Index --> <13612>btree_supplier_s_region_s_nation_s_suppkey, Index scan type --> Index Only Scan, Cost --> 151.25
#
# Bitmap heap scan info:
#
#
# template id: 8, query:
#                 SELECT c_city, s_city, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND c_nation = 'MOROCCO'
#                 AND s_nation = 'MOROCCO'
#                 AND d_year >= 1993 AND d_year <= 1998
#                 GROUP BY c_city, s_city, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_city'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_nation', 'c_city'], 'supplier': ['s_suppkey', 's_nation', 's_city']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_city'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Simple model cost: 304612.85925
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r', 'ix_dwdate_d_year_d_datekey', 'ixn_customer_c_nation_c_custkey_c_ci', 'ixn_supplier_s_nation_s_suppkey_s_ci']
#
#
# Estimated cost without hypothetical indexes: 1685491.38
# Scan costs: {'Index Scan': 0.3, 'Seq Scan': 1505327.16}
#
#
# Estimated cost with hypothetical indexes: 130909.27
# Speedup: 12.8753
#
# Table access info:
#
# Index access info:
# 	Index --> <13577>btree_dwdate_d_year_d_datekey, Index scan type --> Index Only Scan, Cost --> 75.83
# 	Index --> <13594>btree_customer_c_nation_c_city_c_custkey, Index scan type --> Index Only Scan, Cost --> 490.85
# 	Index --> <13570>btree_lineorder_lo_suppkey_lo_orderdate_lo_custkey_lo_re, Index scan type --> Index Only Scan, Cost --> 115.19
# 	Index --> <13612>btree_supplier_s_nation_s_city_s_suppkey, Index scan type --> Index Only Scan, Cost --> 33.34
#
# Bitmap heap scan info:
#
#
# template id: 9, query:
#                 SELECT c_city, s_city, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND (c_city = 'UNITED KI5' OR c_city = 'VIETNAM  8')
#                 AND (s_city = 'UNITED KI5' OR s_city = 'VIETNAM  8')
#                 AND d_year >= 1992 AND d_year <= 1997
#                 GROUP BY c_city, s_city, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_city'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_city'], 'supplier': ['s_suppkey', 's_city']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_city'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Simple model cost: 304534.4842499999
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r', 'ix_dwdate_d_year_d_datekey', 'ix_customer_c_city_c_custkey', 'ix_supplier_s_city_s_suppkey']
#
#
# Estimated cost without hypothetical indexes: 1682417.92
# Scan costs: {'Index Scan': 0.61, 'Seq Scan': 1505530.16}
#
#
# Estimated cost with hypothetical indexes: 29595.94
# Speedup: 56.8462
#
# Table access info:
#
# Index access info:
# 	Index --> <13578>btree_dwdate_d_datekey_d_year, Index scan type --> Index Only Scan, Cost --> 0.05
# 	Index --> <13580>btree_customer_c_city, Index scan type --> Bitmap Index Scan, Cost --> 28.98
# 	Index --> <13570>btree_lineorder_lo_suppkey_lo_orderdate_lo_custkey_lo_re, Index scan type --> Index Only Scan, Cost --> 116.23
# 	Index --> <13586>btree_supplier_s_city_s_suppkey, Index scan type --> Bitmap Index Scan, Cost --> 4.69
#
# Bitmap heap scan info:
# 	Index --> customer, Bitmap Heapscan Cost --> 4006.63
# 	Index --> supplier, Bitmap Heapscan Cost --> 270.63
#
#
# template id: 10, query:
#                 SELECT c_city, s_city, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND (c_city = 'ARGENTINA6' OR c_city = 'MOZAMBIQU1')
#                 AND (s_city = 'ARGENTINA6' OR s_city = 'MOZAMBIQU1')
#                 AND d_yearmonth = 'Nov1998'
#                 GROUP BY c_city, s_city, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_city'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_yearmonth', 'd_datekey'], 'customer': ['c_custkey', 'c_city'], 'supplier': ['s_suppkey', 's_city']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_city'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Simple model cost: 304527.3592499999
# Predicted indexes used in the query plan: ['ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r', 'ixn_dwdate_d_yearmonth_d_datekey_d_ye', 'ix_customer_c_city_c_custkey', 'ix_supplier_s_city_s_suppkey']
#
#
# Estimated cost without hypothetical indexes: 1659017.82
# Scan costs: {'Index Scan': 0.45, 'Seq Scan': 1497134.1099999999}
#
#
# Estimated cost with hypothetical indexes: 19988.18
# Speedup: 82.9999
#
# Table access info:
#
# Index access info:
# 	Index --> <13584>btree_customer_c_custkey_c_city, Index scan type --> Index Only Scan, Cost --> 0.07
# 	Index --> <13574>btree_lineorder_lo_orderdate_lo_suppkey_lo_custkey_lo_re, Index scan type --> Index Only Scan, Cost --> 4.22
# 	Index --> <13579>btree_dwdate_d_yearmonth_d_datekey_d_year, Index scan type --> Index Only Scan, Cost --> 4.55
# 	Index --> <13589>btree_supplier_s_city_s_suppkey, Index scan type --> Bitmap Index Scan, Cost --> 4.59
#
# Bitmap heap scan info:
# 	Index --> supplier, Bitmap Heapscan Cost --> 261.5
#
#
# template id: 11, query:
#                 SELECT d_year, c_nation, SUM(lo_revenue - lo_supplycost) AS profit
#                 FROM dwdate, customer, supplier, part, lineorder
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_partkey = p_partkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'EUROPE'
#                 AND s_region = 'EUROPE'
#                 AND (p_mfgr = 'MFGR#1' OR p_mfgr = 'MFGR#4')
#                 GROUP BY d_year, c_nation
#                 ORDER BY d_year, c_nation;
#             , payload: {'lineorder': ['lo_revenue', 'lo_supplycost'], 'dwdate': ['d_year'], 'customer': ['c_nation']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate', 'lo_partkey'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_region', 'c_nation'], 'part': ['p_partkey', 'p_mfgr'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'customer': ['c_nation']}, group by: {'customer': ['c_nation'], 'dwdate': ['d_year']}
#
# Simple model cost: 759788.725
# Predicted indexes used in the query plan: ['ixn_dwdate_d_datekey_d_ye', 'ixn_customer_c_region_c_custkey_c_na', 'ix_part_p_mfgr_p_partkey', 'ix_supplier_s_region_s_suppkey']
#
#
# Estimated cost without hypothetical indexes: 1774095.96
# Scan costs: {'Seq Scan': 1528883.72}
#
#
# Estimated cost with hypothetical indexes: 1767740.02
# Speedup: 1.0036
#
# Table access info:
# 	Table --> dwdate, Access info --> {'total_cost': 68.56, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
# 	Table --> part, Access info --> {'total_cost': 23488.0, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
# 	Table --> lineorder, Access info --> {'total_cost': 1496462.16, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
#
# Index access info:
# 	Index --> <13724>btree_customer_c_region_c_nation_c_custkey, Index scan type --> Index Only Scan, Cost --> 2371.51
# 	Index --> <13732>btree_supplier_s_region_s_suppkey, Index scan type --> Index Only Scan, Cost --> 137.55
#
# Bitmap heap scan info:
#
#
# template id: 12, query:
#                 SELECT d_year, s_nation, p_category, SUM(lo_revenue - lo_supplycost) AS profit
#                 FROM dwdate, customer, supplier, part, lineorder
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_partkey = p_partkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'AFRICA'
#                 AND s_region = 'AFRICA'
#                 AND (d_year = 1996 OR d_year = 1998)
#                 AND (p_mfgr = 'MFGR#1' OR p_mfgr = 'MFGR#3')
#                 GROUP BY d_year, s_nation, p_category
#                 ORDER BY d_year, s_nation, p_category;
#             , payload: {'lineorder': ['lo_revenue', 'lo_supplycost'], 'dwdate': ['d_year'], 'part': ['p_category'], 'supplier': ['s_nation']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate', 'lo_partkey'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_region', 'c_nation'], 'part': ['p_partkey', 'p_mfgr', 'p_category'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_category'], 'supplier': ['s_nation']}, group by: {'part': ['p_category'], 'supplier': ['s_nation'], 'dwdate': ['d_year']}
#
# Simple model cost: 760816.6750000002
# Predicted indexes used in the query plan: ['ix_dwdate_d_year_d_datekey', 'ixn_part_p_mfgr_p_partkey_p_ca', 'ixn_supplier_s_region_s_suppkey_s_na', 'ix_customer_c_region_c_custkey']
#
#
# Estimated cost without hypothetical indexes: 1743023.08
# Scan costs: {'Seq Scan': 1528896.5}
#
#
# Estimated cost with hypothetical indexes: 1741032.93
# Speedup: 1.0011
#
# Table access info:
# 	Table --> lineorder, Access info --> {'total_cost': 1496462.16, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
#
# Index access info:
# 	Index --> <13736>btree_part_p_partkey_p_category_p_mfgr, Index scan type --> Index Only Scan, Cost --> 0.07
# 	Index --> <13705>btree_dwdate_d_year, Index scan type --> Bitmap Index Scan, Cost --> 6.76
# 	Index --> <13707>btree_dwdate_d_year_d_datekey, Index scan type --> Bitmap Index Scan, Cost --> 10.78
# 	Index --> <13713>btree_customer_c_region_c_custkey, Index scan type --> Index Only Scan, Cost --> 2040.41
# 	Index --> <13747>btree_supplier_s_region_s_suppkey_s_nation, Index scan type --> Index Only Scan, Cost --> 151.25
#
# Bitmap heap scan info:
# 	Index --> dwdate, Bitmap Heapscan Cost --> 71.82
#
#
# template id: 13, query:
#                 SELECT d_year, s_city, p_brand, SUM(lo_revenue - lo_supplycost) AS profit
#                 FROM dwdate, customer, supplier, part, lineorder
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_partkey = p_partkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'MIDDLE EAST'
#                 AND s_nation = 'BRAZIL'
#                 AND (d_year = 1997 OR d_year = 1998)
#                 AND p_category = 'MFGR#41'
#                 GROUP BY d_year, s_city, p_brand
#                 ORDER BY d_year, s_city, p_brand;
#             , payload: {'lineorder': ['lo_revenue', 'lo_supplycost'], 'dwdate': ['d_year'], 'part': ['p_brand'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate', 'lo_partkey'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_nation'], 'part': ['p_partkey', 'p_mfgr', 'p_category'], 'supplier': ['s_suppkey', 's_nation']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand'], 'supplier': ['s_city']}, group by: {'part': ['p_brand'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Simple model cost: 763695.9
# Predicted indexes used in the query plan: ['ix_dwdate_d_year_d_datekey', 'ixn_part_p_category_p_partkey_p_br', 'ixn_supplier_s_nation_s_suppkey_s_ci']
#
#
# Estimated cost without hypothetical indexes: 1694664.79
# Scan costs: {'Index Scan': 0.44, 'Seq Scan': 1518578.5}
#
#
# Estimated cost with hypothetical indexes: 1666775.83
# Speedup: 1.0167
#
# Table access info:
# 	Table --> lineorder, Access info --> {'total_cost': 1496462.16, 'actual_rows': None, 'actual_startup_time': None, 'actual_total_time': None, 'shared_hit_blocks': None, 'shared_read_blocks': None, 'local_hit_blocks': None, 'local_read_blocks': None}
#
# Index access info:
# 	Index --> <13710>btree_customer_c_custkey_c_nation, Index scan type --> Index Scan, Cost --> 0.07
# 	Index --> <13708>btree_dwdate_d_datekey_d_year, Index scan type --> Index Only Scan, Cost --> 0.05
# 	Index --> <13747>btree_supplier_s_nation_s_suppkey_s_city, Index scan type --> Index Only Scan, Cost --> 33.98
# 	Index --> <13726>btree_part_p_category_p_partkey_p_brand, Index scan type --> Index Only Scan, Cost --> 1427.45
#
# Bitmap heap scan info:
#
#
# template id: 14, query:
#                 SELECT lo_linenumber, lo_quantity
#                 FROM lineorder
#                 WHERE lo_linenumber >= 3 AND lo_linenumber <= 4
#                 AND lo_quantity = 18;
#             , payload: {'lineorder': ['lo_linenumber', 'lo_quantity']}, predicates: {'lineorder': ['lo_linenumber', 'lo_quantity']}, order by: {}, group by: {}
#
# Simple model cost: 5805.0
# Predicted indexes used in the query plan: ['ix_lineorder_lo_quantity_lo_linenumber']
#
#
# Estimated cost without hypothetical indexes: 1946358.78
# Scan costs: {'Seq Scan': 1946358.78}
#
#
# Estimated cost with hypothetical indexes: 15652.02
# Speedup: 124.3519
#
# Table access info:
#
# Index access info:
# 	Index --> <13550>btree_lineorder_lo_quantity_lo_linenumber, Index scan type --> Index Only Scan, Cost --> 15652.02
#
# Bitmap heap scan info:
#
#
# Simple model time: 0.0060498714447021484
# What-if time: 0.38967370986938477
