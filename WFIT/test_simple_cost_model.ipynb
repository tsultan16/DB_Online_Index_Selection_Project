# %% [markdown]
# #### Test simple cost model

# %%
# auto reload all modules
# %load_ext autoreload
# %autoreload 2

from simple_cost_model import *
from ssb_qgen_class import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
qgen = QGEN()

example_query = qgen.generate_query(2)
print(example_query)
print(example_query.predicate_dict)
# Out:
# template id: 2, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_yearmonthnum = 199609
#                 AND lo_discount BETWEEN 0  AND 2
#                 AND lo_quantity BETWEEN 6 AND 15;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_yearmonthnum']}, order by: {}, group by: {}
# {'lineorder': [{'column': 'lo_orderdate', 'operator': 'eq', 'value': 'd_datekey', 'join': True}, {'column': 'lo_discount', 'operator': 'range', 'value': (0, 2), 'join': False}, {'column': 'lo_quantity', 'operator': 'range', 'value': (6, 15), 'join': False}], 'dwdate': [{'column': 'd_yearmonthnum', 'operator': 'eq', 'value': 199609, 'join': False}]}

# %%
def actual_cost(query_object, indexes):
    candidate_indexes = list(indexes.values())
    conn = create_connection()
    # drop all existing secondary indexes 
    drop_all_indexes(conn)

    cost_wo_indexes, scan_costs = get_query_cost_estimate(conn, query_object.query_string, show_plan=False)
    print(f"Estimated cost without hypothetical indexes: {cost_wo_indexes}")
    print(f"Scan costs: {scan_costs}")

    # create hypothetical indexes for candidate indexes
    hypothetical_indexes = {}
    created_indexes = bulk_create_hypothetical_indexes(conn, candidate_indexes, return_size=True)
    for i in range(len(created_indexes)):
        hypothetical_indexes[created_indexes[i][0]] = (candidate_indexes[i], created_indexes[i][1]) 
        index_oid, index_size_mb = created_indexes[i]
        #print(f"Index {candidate_indexes[i].index_id} created with oid {index_oid} and size {index_size_mb} MB")

    # get the cost of the query with the hypothetical indexes
    print()
    cost_w_indexes, indexes_used = get_query_cost_estimate_hypo_indexes(conn, query_object.query_string, show_plan=False)
    print(f"\nEstimated cost with hypothetical indexes: {cost_w_indexes}")
    print(f"Speedup: {cost_wo_indexes/cost_w_indexes:.4f}")
    print("\nIndexes used in the query plan:")
    for oid, scan_type, scan_cost in indexes_used:
        print(hypothetical_indexes[oid][0], ", Scan type: ", scan_type, ", Scan cost: ", scan_cost)

    bulk_drop_hypothetical_indexes(conn)
    close_connection(conn)

# %%
# extract candidate indexes
candidate_indexes = extract_query_indexes(example_query, max_key_columns=3, include_cols=True, exclude_pk_indexes_ssb=True)
indexes = {index.index_id: index for index in candidate_indexes}

# %%
# instantiate simple cost model
model = SimpleCost(index_scan_cost_multiplier=1.5)

# make prediction for example query
model.predict(example_query, indexes, verbose=False)
# Out:
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}, Cost: 73870.5
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_yearmonthnum'}, Cost: 0.0

# %%
actual_cost(example_query, indexes)
# Out:
# Estimated cost without hypothetical indexes: 2105042.35
# Scan costs: {'Seq Scan': 2096399.27}
#
#
# Estimated cost with hypothetical indexes: 6815.61
# Speedup: 308.8560
#
# Indexes used in the query plan:
# Index name: ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e, Key cols: ('lo_orderdate', 'lo_quantity', 'lo_discount'), Include cols: ('lo_extendedprice',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  207.38
# Index name: ix_dwdate_d_yearmonthnum_d_datekey, Key cols: ('d_yearmonthnum', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  4.55

# %% [markdown]
# #### Compare predicted and actual access paths for all query templates

# %%
for i in range(1, 15):
    query_object = qgen.generate_query(i)
    print(query_object)
    candidate_indexes = extract_query_indexes(query_object, max_key_columns=3, include_cols=True, exclude_pk_indexes_ssb=True)
    indexes = {index.index_id: index for index in candidate_indexes}
    model.predict(query_object, indexes, verbose=False)
    print("\n\n")
    actual_cost(query_object, indexes)
    print("\n")
# Out:
# template id: 1, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_year = 1993
#                 AND lo_discount BETWEEN 5 AND 7
#                 AND lo_quantity < 25;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_year']}, order by: {}, group by: {}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_discount_lo_orderdate_lo_quantity_lo_e'}, Cost: 102438.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year'}, Cost: 7.5
#
#
#
# Estimated cost without hypothetical indexes: 1972536.97
# Scan costs: {'Seq Scan': 1946433.73}
#
#
# Estimated cost with hypothetical indexes: 119540.67
# Speedup: 16.5010
#
# Indexes used in the query plan:
# Index name: ixn_lineorder_lo_orderdate_lo_discount_lo_quantity_lo_e, Key cols: ('lo_orderdate', 'lo_discount', 'lo_quantity'), Include cols: ('lo_extendedprice',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  279.76
# Index name: ix_dwdate_d_year_d_datekey, Key cols: ('d_year', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  14.42
#
#
# template id: 2, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_yearmonthnum = 199611
#                 AND lo_discount BETWEEN 7  AND 9
#                 AND lo_quantity BETWEEN 2 AND 11;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_yearmonthnum']}, order by: {}, group by: {}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}, Cost: 74469.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_yearmonthnum'}, Cost: 0.0
#
#
#
# Estimated cost without hypothetical indexes: 2105096.51
# Scan costs: {'Seq Scan': 2096399.27}
#
#
# Estimated cost with hypothetical indexes: 6843.19
# Speedup: 307.6192
#
# Indexes used in the query plan:
# Index name: ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e, Key cols: ('lo_orderdate', 'lo_quantity', 'lo_discount'), Include cols: ('lo_extendedprice',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  208.17
# Index name: ix_dwdate_d_yearmonthnum_d_datekey, Key cols: ('d_yearmonthnum', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  4.55
#
#
# template id: 3, query:
#                 SELECT SUM(lo_extendedprice * lo_discount) AS revenue
#                 FROM lineorder, dwdate
#                 WHERE lo_orderdate = d_datekey
#                 AND d_weeknuminyear = 33
#                 AND d_year = 1992
#                 AND lo_discount BETWEEN 0 AND 2
#                 AND lo_quantity BETWEEN 10 AND 19;
#             , payload: {'lineorder': ['lo_extendedprice', 'lo_discount']}, predicates: {'lineorder': ['lo_orderdate', 'lo_discount', 'lo_quantity'], 'dwdate': ['d_datekey', 'd_weeknuminyear']}, order by: {}, group by: {}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_quantity_lo_orderdate_lo_discount_lo_e'}, Cost: 74506.5
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_weeknuminyear'}, Cost: 0.0
#
#
#
# Estimated cost without hypothetical indexes: 2104977.11
# Scan costs: {'Seq Scan': 2096405.6600000001}
#
#
# Estimated cost with hypothetical indexes: 1650.9
# Speedup: 1275.0482
#
# Indexes used in the query plan:
# Index name: ixn_lineorder_lo_orderdate_lo_quantity_lo_discount_lo_e, Key cols: ('lo_orderdate', 'lo_quantity', 'lo_discount'), Include cols: ('lo_extendedprice',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  208.83
# Index name: ix_dwdate_d_weeknuminyear_d_datekey, Key cols: ('d_weeknuminyear', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  4.4
#
#
# template id: 4, query:
#                 SELECT SUM(lo_revenue), d_year, p_brand
#                 FROM lineorder, dwdate, part, supplier
#                 WHERE lo_orderdate = d_datekey
#                 AND lo_partkey = p_partkey
#                 AND lo_suppkey = s_suppkey
#                 AND p_category = 'MFGR#53'
#                 AND s_region = 'EUROPE'
#                 GROUP BY d_year, p_brand
#                 ORDER BY d_year, p_brand;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'part': ['p_brand']}, predicates: {'lineorder': ['lo_orderdate', 'lo_partkey', 'lo_suppkey'], 'dwdate': ['d_year', 'd_datekey'], 'part': ['p_partkey', 'p_category', 'p_brand'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand']}, group by: {'dwdate': ['d_year'], 'part': ['p_brand']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_partkey_lo_suppkey_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_dwdate_d_datekey_d_ye'}, Cost: 10.5
# Table: part, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_part_p_category_p_partkey_p_br'}, Cost: 217.5
# Table: supplier, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_supplier_s_region'}, Cost: 96.0
#
#
#
# Estimated cost without hypothetical indexes: 1688277.31
# Scan costs: {'Seq Scan': 1518565.72}
#
#
# Estimated cost with hypothetical indexes: 230612.17
# Speedup: 7.3209
#
# Indexes used in the query plan:
# Index name: ix_supplier_s_region_s_suppkey, Key cols: ('s_region', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  137.55
# Index name: ixn_lineorder_lo_partkey_lo_suppkey_lo_orderdate_lo_r, Key cols: ('lo_partkey', 'lo_suppkey', 'lo_orderdate'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  5.69
# Index name: ix_part_p_category_p_brand_p_partkey, Key cols: ('p_category', 'p_brand', 'p_partkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  1440.12
#
#
# template id: 5, query:
#                 SELECT SUM(lo_revenue), d_year, p_brand
#                 FROM lineorder, dwdate, part, supplier
#                 WHERE lo_orderdate = d_datekey
#                 AND lo_partkey = p_partkey
#                 AND lo_suppkey = s_suppkey
#                 AND p_brand BETWEEN 'MFGR#5496' AND 'MFGR#5503'
#                 AND s_region = 'EUROPE'
#                 GROUP BY d_year, p_brand
#                 ORDER BY d_year, p_brand;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'part': ['p_brand']}, predicates: {'lineorder': ['lo_orderdate', 'lo_partkey', 'lo_suppkey'], 'dwdate': ['d_year', 'd_datekey'], 'part': ['p_partkey', 'p_category', 'p_brand'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand']}, group by: {'dwdate': ['d_year'], 'part': ['p_brand']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_partkey_lo_suppkey_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_dwdate_d_datekey_d_ye'}, Cost: 10.5
# Table: part, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ix_part_p_brand_p_partkey'}, Cost: 42.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_supplier_s_region'}, Cost: 96.0
#
#
#
# Estimated cost without hypothetical indexes: 1694108.99
# Scan costs: {'Seq Scan': 1520565.72}
#
#
# Estimated cost with hypothetical indexes: 59875.47
# Speedup: 28.2939
#
# Indexes used in the query plan:
# Index name: ix_supplier_s_region_s_suppkey, Key cols: ('s_region', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  137.55
# Index name: ixn_lineorder_lo_partkey_lo_suppkey_lo_orderdate_lo_r, Key cols: ('lo_partkey', 'lo_suppkey', 'lo_orderdate'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  5.84
# Index name: ix_part_p_brand_p_partkey, Key cols: ('p_brand', 'p_partkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  370.37
#
#
# template id: 6, query:
#                 SELECT SUM(lo_revenue), d_year, p_brand
#                 FROM lineorder, dwdate, part, supplier
#                 WHERE lo_orderdate = d_datekey
#                 AND lo_partkey = p_partkey
#                 AND lo_suppkey = s_suppkey
#                 AND p_brand = 'MFGR#152'
#                 AND s_region = 'AFRICA'
#                 GROUP BY d_year, p_brand
#                 ORDER BY d_year, p_brand;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'part': ['p_brand']}, predicates: {'lineorder': ['lo_orderdate', 'lo_partkey', 'lo_suppkey'], 'dwdate': ['d_year', 'd_datekey'], 'part': ['p_partkey', 'p_category', 'p_brand'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand']}, group by: {'dwdate': ['d_year'], 'part': ['p_brand']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_orderdate_lo_partkey_lo_suppkey_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_dwdate_d_datekey_d_ye'}, Cost: 10.5
# Table: part, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ix_part_p_brand_p_partkey'}, Cost: 42.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_supplier_s_region'}, Cost: 91.5
#
#
#
# Estimated cost without hypothetical indexes: 1684082.85
# Scan costs: {'Seq Scan': 1518018.72, 'Index Scan': 0.31}
#
#
# Estimated cost with hypothetical indexes: 6075.17
# Speedup: 277.2075
#
# Indexes used in the query plan:
# Index name: ix_supplier_s_region_s_suppkey, Key cols: ('s_region', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  131.25
# Index name: ixn_lineorder_lo_partkey_lo_suppkey_lo_orderdate_lo_r, Key cols: ('lo_partkey', 'lo_suppkey', 'lo_orderdate'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  5.9
# Index name: ix_part_p_brand_p_partkey, Key cols: ('p_brand', 'p_partkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  37.96
#
#
# template id: 7, query:
#                 SELECT c_nation, s_nation, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'AFRICA'
#                 AND s_region = 'AFRICA'
#                 AND d_year >= 1993 AND d_year <= 1998
#                 GROUP BY c_nation, s_nation, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_nation'], 'supplier': ['s_nation']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_region', 'c_nation'], 'supplier': ['s_suppkey', 's_region', 's_nation']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_nation'], 'supplier': ['s_nation'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}, Cost: 9.0
# Table: customer, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_customer_c_region_c_custkey_c_na'}, Cost: 385.5
# Table: supplier, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_supplier_s_region_s_suppkey_s_na'}, Cost: 24.0
#
#
#
# Estimated cost without hypothetical indexes: 1720164.09
# Scan costs: {'Seq Scan': 1505408.5}
#
#
# Estimated cost with hypothetical indexes: 599653.8
# Speedup: 2.8686
#
# Indexes used in the query plan:
# Index name: ix_dwdate_d_year_d_datekey, Key cols: ('d_year', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  75.83
# Index name: ix_customer_c_region_c_nation_c_custkey, Key cols: ('c_region', 'c_nation', 'c_custkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  2384.41
# Index name: ixn_lineorder_lo_suppkey_lo_orderdate_lo_custkey_lo_r, Key cols: ('lo_suppkey', 'lo_orderdate', 'lo_custkey'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  110.69
# Index name: ix_supplier_s_region_s_nation_s_suppkey, Key cols: ('s_region', 's_nation', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  151.25
#
#
# template id: 8, query:
#                 SELECT c_city, s_city, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND c_nation = 'EGYPT'
#                 AND s_nation = 'EGYPT'
#                 AND d_year >= 1992 AND d_year <= 1997
#                 GROUP BY c_city, s_city, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_city'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_nation', 'c_city'], 'supplier': ['s_suppkey', 's_nation', 's_city']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_city'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}, Cost: 9.0
# Table: customer, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_customer_c_nation_c_custkey_c_ci'}, Cost: 81.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_supplier_s_nation_s_suppkey_s_ci'}, Cost: 4.5
#
#
#
# Estimated cost without hypothetical indexes: 1688379.91
# Scan costs: {'Index Scan': 0.3, 'Seq Scan': 1505327.16}
#
#
# Estimated cost with hypothetical indexes: 139727.16
# Speedup: 12.0834
#
# Indexes used in the query plan:
# Index name: ix_dwdate_d_year_d_datekey, Key cols: ('d_year', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  75.87
# Index name: ix_customer_c_nation_c_city_c_custkey, Key cols: ('c_nation', 'c_city', 'c_custkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  491.72
# Index name: ixn_lineorder_lo_suppkey_lo_orderdate_lo_custkey_lo_r, Key cols: ('lo_suppkey', 'lo_orderdate', 'lo_custkey'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  115.13
# Index name: ix_supplier_s_nation_s_city_s_suppkey, Key cols: ('s_nation', 's_city', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  34.04
#
#
# template id: 9, query:
#                 SELECT c_city, s_city, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND (c_city = 'JORDAN   2' OR c_city = 'EGYPT    5')
#                 AND (s_city = 'JORDAN   2' OR s_city = 'EGYPT    5')
#                 AND d_year >= 1992 AND d_year <= 1997
#                 GROUP BY c_city, s_city, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_city'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_city'], 'supplier': ['s_suppkey', 's_city']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_city'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ix_dwdate_d_year_d_datekey'}, Cost: 9.0
# Table: customer, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_customer_c_city'}, Cost: 0.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_supplier_s_city'}, Cost: 0.0
#
#
#
# Estimated cost without hypothetical indexes: 1682432.8
# Scan costs: {'Index Scan': 0.61, 'Seq Scan': 1505530.16}
#
#
# Estimated cost with hypothetical indexes: 30232.76
# Speedup: 55.6493
#
# Indexes used in the query plan:
# Index name: ix_dwdate_d_datekey_d_year, Key cols: ('d_datekey', 'd_year'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  0.05
# Index name: ix_customer_c_city, Key cols: ('c_city',), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  28.98
# Index name: ix_customer_c_city, Key cols: ('c_city',), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  28.98
# Index name: ixn_lineorder_lo_suppkey_lo_orderdate_lo_custkey_lo_r, Key cols: ('lo_suppkey', 'lo_orderdate', 'lo_custkey'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  116.23
# Index name: ix_supplier_s_city_s_suppkey, Key cols: ('s_city', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  4.59
# Index name: ix_supplier_s_city_s_suppkey, Key cols: ('s_city', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  4.72
#
#
# template id: 10, query:
#                 SELECT c_city, s_city, d_year, SUM(lo_revenue) AS revenue
#                 FROM customer, lineorder, supplier, dwdate
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_orderdate = d_datekey
#                 AND (c_city = 'ALGERIA  6' OR c_city = 'VIETNAM  0')
#                 AND (s_city = 'ALGERIA  6' OR s_city = 'VIETNAM  0')
#                 AND d_yearmonth = 'Jun1994'
#                 GROUP BY c_city, s_city, d_year
#                 ORDER BY d_year ASC, revenue DESC;
#             , payload: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year'], 'customer': ['c_city'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate'], 'dwdate': ['d_yearmonth', 'd_datekey'], 'customer': ['c_custkey', 'c_city'], 'supplier': ['s_suppkey', 's_city']}, order by: {'lineorder': ['lo_revenue'], 'dwdate': ['d_year']}, group by: {'customer': ['c_city'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_lineorder_lo_custkey_lo_suppkey_lo_orderdate_lo_r'}, Cost: 374913.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_yearmonth'}, Cost: 0.0
# Table: customer, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_customer_c_city'}, Cost: 0.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_supplier_s_city'}, Cost: 0.0
#
#
#
# Estimated cost without hypothetical indexes: 1659017.82
# Scan costs: {'Index Scan': 0.45, 'Seq Scan': 1497134.1099999999}
#
#
# Estimated cost with hypothetical indexes: 19988.18
# Speedup: 82.9999
#
# Indexes used in the query plan:
# Index name: ix_customer_c_custkey_c_city, Key cols: ('c_custkey', 'c_city'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  0.07
# Index name: ixn_lineorder_lo_orderdate_lo_suppkey_lo_custkey_lo_r, Key cols: ('lo_orderdate', 'lo_suppkey', 'lo_custkey'), Include cols: ('lo_revenue',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  4.22
# Index name: ixn_dwdate_d_yearmonth_d_datekey_d_ye, Key cols: ('d_yearmonth', 'd_datekey'), Include cols: ('d_year',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  4.55
# Index name: ix_supplier_s_city_s_suppkey, Key cols: ('s_city', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  4.59
# Index name: ix_supplier_s_city_s_suppkey, Key cols: ('s_city', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  4.59
#
#
# template id: 11, query:
#                 SELECT d_year, c_nation, SUM(lo_revenue - lo_supplycost) AS profit
#                 FROM dwdate, customer, supplier, part, lineorder
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_partkey = p_partkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'AFRICA'
#                 AND s_region = 'AFRICA'
#                 AND (p_mfgr = 'MFGR#2' OR p_mfgr = 'MFGR#5')
#                 GROUP BY d_year, c_nation
#                 ORDER BY d_year, c_nation;
#             , payload: {'lineorder': ['lo_revenue', 'lo_supplycost'], 'dwdate': ['d_year'], 'customer': ['c_nation']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate', 'lo_partkey'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_region', 'c_nation'], 'part': ['p_partkey', 'p_mfgr'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'customer': ['c_nation']}, group by: {'customer': ['c_nation'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Sequential Scan'}, Cost: 759319.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_dwdate_d_datekey_d_ye'}, Cost: 10.5
# Table: customer, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_customer_c_region_c_custkey_c_na'}, Cost: 385.5
# Table: part, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_part_p_mfgr'}, Cost: 0.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_supplier_s_region'}, Cost: 91.5
#
#
#
# Estimated cost without hypothetical indexes: 1771330.13
# Scan costs: {'Seq Scan': 1528883.72}
#
#
# Estimated cost with hypothetical indexes: 1764539.22
# Speedup: 1.0038
#
# Indexes used in the query plan:
# Index name: ix_part_p_mfgr, Key cols: ('p_mfgr',), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  3275.65
# Index name: ix_part_p_mfgr, Key cols: ('p_mfgr',), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  3380.25
# Index name: ix_customer_c_region_c_nation_c_custkey, Key cols: ('c_region', 'c_nation', 'c_custkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  2384.41
# Index name: ix_supplier_s_region_s_suppkey, Key cols: ('s_region', 's_suppkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  131.25
#
#
# template id: 12, query:
#                 SELECT d_year, s_nation, p_category, SUM(lo_revenue - lo_supplycost) AS profit
#                 FROM dwdate, customer, supplier, part, lineorder
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_partkey = p_partkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'ASIA'
#                 AND s_region = 'ASIA'
#                 AND (d_year = 1995 OR d_year = 1996)
#                 AND (p_mfgr = 'MFGR#4' OR p_mfgr = 'MFGR#5')
#                 GROUP BY d_year, s_nation, p_category
#                 ORDER BY d_year, s_nation, p_category;
#             , payload: {'lineorder': ['lo_revenue', 'lo_supplycost'], 'dwdate': ['d_year'], 'part': ['p_category'], 'supplier': ['s_nation']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate', 'lo_partkey'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_region', 'c_nation'], 'part': ['p_partkey', 'p_mfgr', 'p_category'], 'supplier': ['s_suppkey', 's_region']}, order by: {'dwdate': ['d_year'], 'part': ['p_category'], 'supplier': ['s_nation']}, group by: {'part': ['p_category'], 'supplier': ['s_nation'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Sequential Scan'}, Cost: 759319.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year'}, Cost: 0.0
# Table: part, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_part_p_mfgr'}, Cost: 0.0
# Table: supplier, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_supplier_s_region_s_suppkey_s_na'}, Cost: 25.5
# Table: customer, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_customer_c_region'}, Cost: 1509.0
#
#
#
# Estimated cost without hypothetical indexes: 1745078.1
# Scan costs: {'Seq Scan': 1528896.5}
#
#
# Estimated cost with hypothetical indexes: 1744761.97
# Speedup: 1.0002
#
# Indexes used in the query plan:
# Index name: ix_part_p_partkey_p_category_p_mfgr, Key cols: ('p_partkey', 'p_category', 'p_mfgr'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  0.07
# Index name: ix_dwdate_d_year_d_datekey, Key cols: ('d_year', 'd_datekey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  10.78
# Index name: ix_dwdate_d_year, Key cols: ('d_year',), Include cols: (), Current OID: None, Size: None MB , Scan type:  Bitmap Index Scan , Scan cost:  6.77
# Index name: ix_customer_c_region_c_custkey, Key cols: ('c_region', 'c_custkey'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  2047.74
# Index name: ixn_supplier_s_region_s_suppkey_s_na, Key cols: ('s_region', 's_suppkey'), Include cols: ('s_nation',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  158.05
#
#
# template id: 13, query:
#                 SELECT d_year, s_city, p_brand, SUM(lo_revenue - lo_supplycost) AS profit
#                 FROM dwdate, customer, supplier, part, lineorder
#                 WHERE lo_custkey = c_custkey
#                 AND lo_suppkey = s_suppkey
#                 AND lo_partkey = p_partkey
#                 AND lo_orderdate = d_datekey
#                 AND c_region = 'AFRICA'
#                 AND s_nation = 'EGYPT'
#                 AND (d_year = 1994 OR d_year = 1995)
#                 AND p_category = 'MFGR#25'
#                 GROUP BY d_year, s_city, p_brand
#                 ORDER BY d_year, s_city, p_brand;
#             , payload: {'lineorder': ['lo_revenue', 'lo_supplycost'], 'dwdate': ['d_year'], 'part': ['p_brand'], 'supplier': ['s_city']}, predicates: {'lineorder': ['lo_custkey', 'lo_suppkey', 'lo_orderdate', 'lo_partkey'], 'dwdate': ['d_year', 'd_datekey'], 'customer': ['c_custkey', 'c_nation'], 'part': ['p_partkey', 'p_mfgr', 'p_category'], 'supplier': ['s_suppkey', 's_nation']}, order by: {'dwdate': ['d_year'], 'part': ['p_brand'], 'supplier': ['s_city']}, group by: {'part': ['p_brand'], 'supplier': ['s_city'], 'dwdate': ['d_year']}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Sequential Scan'}, Cost: 759319.0
# Table: dwdate, Cheapest path: {'scan_type': 'Index Scan', 'index_id': 'ix_dwdate_d_year'}, Cost: 0.0
# Table: part, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_part_p_category_p_partkey_p_br'}, Cost: 223.5
# Table: supplier, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ixn_supplier_s_nation_s_suppkey_s_ci'}, Cost: 4.5
# Table: customer, Cheapest path: {'scan_type': 'Sequential Scan'}, Cost: 4166.0
#
#
#
# Estimated cost without hypothetical indexes: 1695167.53
# Scan costs: {'Index Scan': 0.44, 'Seq Scan': 1518578.5}
#
#
# Estimated cost with hypothetical indexes: 1667042.62
# Speedup: 1.0169
#
# Indexes used in the query plan:
# Index name: ix_customer_c_custkey_c_nation, Key cols: ('c_custkey', 'c_nation'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Scan , Scan cost:  0.07
# Index name: ix_dwdate_d_datekey_d_year, Key cols: ('d_datekey', 'd_year'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  0.05
# Index name: ixn_part_p_category_p_partkey_p_br, Key cols: ('p_category', 'p_partkey'), Include cols: ('p_brand',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  1473.65
# Index name: ixn_supplier_s_nation_s_suppkey_s_ci, Key cols: ('s_nation', 's_suppkey'), Include cols: ('s_city',), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  34.04
#
#
# template id: 14, query:
#                 SELECT lo_linenumber, lo_quantity
#                 FROM lineorder
#                 WHERE lo_linenumber >= 2 AND lo_linenumber <= 3
#                 AND lo_quantity = 50;
#             , payload: {'lineorder': ['lo_linenumber', 'lo_quantity']}, predicates: {'lineorder': ['lo_linenumber', 'lo_quantity']}, order by: {}, group by: {}
#
# Cheapest access paths:
# Table: lineorder, Cheapest path: {'scan_type': 'Index Only Scan', 'index_id': 'ix_lineorder_lo_quantity_lo_linenumber'}, Cost: 5338.5
#
#
#
# Estimated cost without hypothetical indexes: 1946358.78
# Scan costs: {'Seq Scan': 1946358.78}
#
#
# Estimated cost with hypothetical indexes: 17410.29
# Speedup: 111.7936
#
# Indexes used in the query plan:
# Index name: ix_lineorder_lo_quantity_lo_linenumber, Key cols: ('lo_quantity', 'lo_linenumber'), Include cols: (), Current OID: None, Size: None MB , Scan type:  Index Only Scan , Scan cost:  17410.29
