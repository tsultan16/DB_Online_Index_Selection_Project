# %% [markdown]
# #### Test postgres DB, collect table statistics

# %%
import psycopg2
import numpy as np
from pg_utils import *

# %% [markdown]
# #### Connect to the postgres database

# %%
conn = create_connection()
close_connection(conn)

# %% [markdown]
# ### Fetch some data and print it out

# %%
def execute_query(conn, query, print_results=True):
    # Create a cursor object
    cur = conn.cursor()

    # Execute a query
    cur.execute(query)

    # Fetch and print the results
    rows = cur.fetchall()

    if print_results:
        for row in rows:
            print(row)

    # Close the cursor
    cur.close()

    return rows


query = """
        SELECT * 
        FROM lineorder
        LIMIT 10 
        """

conn = create_connection()
execute_query(conn, query)
close_connection(conn)
# Out:
# (1, 1, 257368, 465569, 8273, datetime.date(1995, 2, 18), '2-HIGH', '0', 17, Decimal('2608718'), Decimal('9783671'), Decimal('4'), Decimal('2504369'), Decimal('92072'), Decimal('2'), datetime.date(1995, 3, 31), 'TRUCK')
# (1, 2, 257368, 201928, 1630, datetime.date(1995, 2, 18), '2-HIGH', '0', 36, Decimal('6587676'), Decimal('9783671'), Decimal('9'), Decimal('5994785'), Decimal('109794'), Decimal('6'), datetime.date(1995, 4, 16), 'MAIL')
# (1, 3, 257368, 191100, 709, datetime.date(1995, 2, 18), '2-HIGH', '0', 8, Decimal('952880'), Decimal('9783671'), Decimal('10'), Decimal('857592'), Decimal('71466'), Decimal('2'), datetime.date(1995, 4, 22), 'REG AIR')
# (2, 1, 182365, 318510, 10657, datetime.date(1996, 1, 30), '2-HIGH', '0', 38, Decimal('5808300'), Decimal('22125006'), Decimal('0'), Decimal('5808300'), Decimal('91710'), Decimal('5'), datetime.date(1996, 3, 14), 'RAIL')
# (2, 2, 182365, 583525, 6015, datetime.date(1996, 1, 30), '2-HIGH', '0', 30, Decimal('4825500'), Decimal('22125006'), Decimal('5'), Decimal('4584225'), Decimal('96510'), Decimal('1'), datetime.date(1996, 4, 15), 'FOB')
# (2, 3, 182365, 300491, 1372, datetime.date(1996, 1, 30), '2-HIGH', '0', 44, Decimal('6562512'), Decimal('22125006'), Decimal('7'), Decimal('6103136'), Decimal('89488'), Decimal('3'), datetime.date(1996, 4, 9), 'SHIP')
# (2, 4, 182365, 137408, 13818, datetime.date(1996, 1, 30), '2-HIGH', '0', 37, Decimal('5347980'), Decimal('22125006'), Decimal('9'), Decimal('4866661'), Decimal('86724'), Decimal('5'), datetime.date(1996, 4, 14), 'AIR')
# (3, 1, 206119, 12891, 19585, datetime.date(1996, 8, 17), '1-URGENT', '0', 45, Decimal('8117505'), Decimal('20025099'), Decimal('6'), Decimal('7630454'), Decimal('108233'), Decimal('0'), datetime.date(1996, 11, 7), 'AIR')
# (3, 2, 206119, 57107, 16666, datetime.date(1996, 8, 17), '1-URGENT', '0', 49, Decimal('5214090'), Decimal('20025099'), Decimal('10'), Decimal('4692681'), Decimal('63846'), Decimal('0'), datetime.date(1996, 10, 23), 'RAIL')
# (3, 3, 206119, 385345, 14090, datetime.date(1996, 8, 17), '1-URGENT', '0', 27, Decimal('3861891'), Decimal('20025099'), Decimal('6'), Decimal('3630177'), Decimal('85819'), Decimal('7'), datetime.date(1996, 9, 25), 'SHIP')

# %% [markdown]
# #### Gathering table statistics.

# %%
# Dictionary mapping table names to a list of tuples (column_name, data_type)
ssb_schema = {
    "lineorder": [
        ("lo_orderkey", "INT"),
        ("lo_linenumber", "INT"),
        ("lo_custkey", "INT"),
        ("lo_partkey", "INT"),
        ("lo_suppkey", "INT"),
        ("lo_orderdate", "DATE"),
        ("lo_orderpriority", "VARCHAR(15)"),
        ("lo_shippriority", "CHAR(1)"),
        ("lo_quantity", "INT"),
        ("lo_extendedprice", "NUMERIC"),
        ("lo_ordtotalprice", "NUMERIC"),
        ("lo_discount", "NUMERIC"),
        ("lo_revenue", "NUMERIC"),
        ("lo_supplycost", "NUMERIC"),
        ("lo_tax", "INT"),
        ("lo_commitdate", "DATE"),
        ("lo_shipmode", "VARCHAR(7)")
    ],
    "part": [
        ("p_partkey", "INT"),
        ("p_name", "VARCHAR(22)"),
        ("p_mfgr", "CHAR(6)"),
        ("p_category", "CHAR(7)"),
        ("p_brand", "CHAR(9)"),
        ("p_color", "VARCHAR(11)"),
        ("p_type", "VARCHAR(25)"),
        ("p_size", "INT"),
        ("p_container", "VARCHAR(10)")
    ],
    "supplier": [
        ("s_suppkey", "INT"),
        ("s_name", "CHAR(25)"),
        ("s_address", "VARCHAR(25)"),
        ("s_city", "CHAR(10)"),
        ("s_nation", "VARCHAR(15)"),
        ("s_region", "VARCHAR(12)"),
        ("s_phone", "CHAR(15)")
    ],
    "customer": [
        ("c_custkey", "INT"),
        ("c_name", "CHAR(18)"),
        ("c_address", "VARCHAR(25)"),
        ("c_city", "CHAR(10)"),
        ("c_nation", "VARCHAR(15)"),
        ("c_region", "VARCHAR(12)"),
        ("c_phone", "CHAR(15)"),
        ("c_mktsegment", "VARCHAR(10)")
    ],
    "dwdate": [
        ("d_datekey", "DATE"),
        ("d_date", "VARCHAR(18)"),
        ("d_dayofweek", "VARCHAR(9)"),
        ("d_month", "VARCHAR(9)"),
        ("d_year", "INT"),
        ("d_yearmonthnum", "INT"),
        ("d_yearmonth", "CHAR(7)"),
        ("d_daynuminweek", "INT"),
        ("d_daynuminmonth", "INT"),
        ("d_daynuminyear", "INT"),
        ("d_monthnuminyear", "INT"),
        ("d_weeknuminyear", "INT"),
        ("d_sellingseason", "VARCHAR(9)"),
        ("d_lastdayinweekfl", "BIT"),
        ("d_lastdayinmonthfl", "BIT"),
        ("d_holidayfl", "BIT"),
        ("d_weekdayfl", "BIT")
    ]
}

# Example usage: print the schema for the 'lineorder' table
print(ssb_schema["lineorder"])
# Out:
# [('lo_orderkey', 'INT'), ('lo_linenumber', 'INT'), ('lo_custkey', 'INT'), ('lo_partkey', 'INT'), ('lo_suppkey', 'INT'), ('lo_orderdate', 'DATE'), ('lo_orderpriority', 'VARCHAR(15)'), ('lo_shippriority', 'CHAR(1)'), ('lo_quantity', 'INT'), ('lo_extendedprice', 'NUMERIC'), ('lo_ordtotalprice', 'NUMERIC'), ('lo_discount', 'NUMERIC'), ('lo_revenue', 'NUMERIC'), ('lo_supplycost', 'NUMERIC'), ('lo_tax', 'INT'), ('lo_commitdate', 'DATE'), ('lo_shipmode', 'VARCHAR(7)')]

# %%
def collect_stats(table_name, columns):

    # Connect to the PostgreSQL database
    conn =create_connection()
    
    print(f"Collecting stats...")
    print(f"Table --> {table_name}")

    # Create a cursor
    cursor = conn.cursor()

    # Prepare a dictionary to store statistics
    stats = {}

    # Iterate over each column and its data type
    for column_name, data_type in columns:
        print(f"Column --> {column_name}")

        if 'INT' in data_type or 'DECIMAL' in data_type or 'NUMERIC' in data_type:
            query = f"""
            SELECT MIN({column_name}), MAX({column_name}), COUNT(*), COUNT(DISTINCT {column_name})
            FROM {table_name};
            """
            cursor.execute(query)
            min_val, max_val, total_count, distinct_count = cursor.fetchone()
            stats[column_name] = {
                'min': min_val,
                'max': max_val,
                'total_count': total_count,
                'distinct_count': distinct_count}

            if distinct_count <= 1000:
                histogram_query = f"""
                SELECT {column_name}, COUNT(*) AS frequency
                FROM {table_name}
                GROUP BY {column_name}
                ORDER BY {column_name};
                """
                cursor.execute(histogram_query)
                histogram = cursor.fetchall()
                stats[column_name]['histogram'] = {value: count for value, count in histogram}
                
            else:
                histogram = None
                stats[column_name]['histogram'] = None

            print(f"Collected stats for {column_name}: min={min_val}, max={max_val}, total_count={total_count}, distinct_count={distinct_count}, histogram={histogram}")

        
        elif 'CHAR' in data_type or 'VARCHAR' in data_type:
            query = f"""
            SELECT MIN({column_name}), MAX({column_name}), COUNT(*), COUNT(DISTINCT {column_name})
            FROM {table_name};
            """
            cursor.execute(query)
            min_val, max_val, total_count, distinct_count = cursor.fetchone()
            stats[column_name] = {
                'min': min_val,
                'max': max_val,
                'total_count': total_count,
                'distinct_count': distinct_count}
            
            if distinct_count <= 1000:
                histogram_query = f"""
                SELECT {column_name}, COUNT(*) AS frequency
                FROM {table_name}
                GROUP BY {column_name}
                ORDER BY {column_name};
                """
                cursor.execute(histogram_query)
                histogram = cursor.fetchall()
                stats[column_name]['histogram'] = {value: count for value, count in histogram}
                
            else:
                histogram = None
                stats[column_name]['histogram'] = None

            print(f"Collected stats for {column_name}: min={min_val}, max={max_val}, total_count={total_count}, distinct_count={distinct_count}, histogram={histogram}")
       
        elif 'DATE' in data_type:
            query = f"""
            SELECT MIN({column_name}), MAX({column_name})
            FROM {table_name};
            """
            cursor.execute(query)
            min_date, max_date = cursor.fetchone()
            stats[column_name] = {
                'min': min_date,
                'max': max_date
            }

            print(f"Collected stats for {column_name}: min={min_date}, max={max_date}")


    # Close the database connection
    cursor.close()
    close_connection(conn)

    return stats

# %%
table = 'customer'
customer_stats = collect_stats(table, columns=ssb_schema[table])

print(customer_stats)
# Out:
# Collecting stats...
# Table --> customer
# Column --> c_custkey
# Collected stats for c_custkey: min=1, max=300000, total_count=300000, distinct_count=300000, histogram=None
# Column --> c_name
# Collected stats for c_name: min=Customer#000000001, max=Customer#000300000, total_count=300000, distinct_count=300000, histogram=None
# Column --> c_address
# Collected stats for c_address: min=   2Ksa,h, max=zzyQcZpC50YD, total_count=300000, distinct_count=300000, histogram=None
# Column --> c_city
# Collected stats for c_city: min=ALGERIA  0, max=VIETNAM  9, total_count=300000, distinct_count=250, histogram=[('ALGERIA  0', 1161), ('ALGERIA  1', 1181), ('ALGERIA  2', 1173), ('ALGERIA  3', 1225), ('ALGERIA  4', 1191), ('ALGERIA  5', 1208), ('ALGERIA  6', 1176), ('ALGERIA  7', 1187), ('ALGERIA  8', 1154), ('ALGERIA  9', 1186), ('ARGENTINA0', 1229), ('ARGENTINA1', 1155), ('ARGENTINA2', 1218), ('ARGENTINA3', 1203), ('ARGENTINA4', 1166), ('ARGENTINA5', 1205), ('ARGENTINA6', 1166), ('ARGENTINA7', 1190), ('ARGENTINA8', 1221), ('ARGENTINA9', 1169), ('BRAZIL   0', 1158), ('BRAZIL   1', 1215), ('BRAZIL   2', 1251), ('BRAZIL   3', 1133), ('BRAZIL   4', 1218), ('BRAZIL   5', 1241), ('BRAZIL   6', 1262), ('BRAZIL   7', 1185), ('BRAZIL   8', 1173), ('BRAZIL   9', 1228), ('CANADA   0', 1152), ('CANADA   1', 1268), ('CANADA   2', 1154), ('CANADA   3', 1224), ('CANADA   4', 1267), ('CANADA   5', 1138), ('CANADA   6', 1206), ('CANADA   7', 1172), ('CANADA   8', 1240), ('CANADA   9', 1141), ('CHINA    0', 1226), ('CHINA    1', 1152), ('CHINA    2', 1215), ('CHINA    3', 1179), ('CHINA    4', 1178), ('CHINA    5', 1228), ('CHINA    6', 1209), ('CHINA    7', 1191), ('CHINA    8', 1224), ('CHINA    9', 1214), ('EGYPT    0', 1212), ('EGYPT    1', 1175), ('EGYPT    2', 1128), ('EGYPT    3', 1165), ('EGYPT    4', 1181), ('EGYPT    5', 1114), ('EGYPT    6', 1234), ('EGYPT    7', 1220), ('EGYPT    8', 1171), ('EGYPT    9', 1270), ('ETHIOPIA 0', 1218), ('ETHIOPIA 1', 1212), ('ETHIOPIA 2', 1212), ('ETHIOPIA 3', 1177), ('ETHIOPIA 4', 1210), ('ETHIOPIA 5', 1190), ('ETHIOPIA 6', 1287), ('ETHIOPIA 7', 1213), ('ETHIOPIA 8', 1208), ('ETHIOPIA 9', 1217), ('FRANCE   0', 1170), ('FRANCE   1', 1223), ('FRANCE   2', 1197), ('FRANCE   3', 1269), ('FRANCE   4', 1222), ('FRANCE   5', 1225), ('FRANCE   6', 1166), ('FRANCE   7', 1248), ('FRANCE   8', 1243), ('FRANCE   9', 1205), ('GERMANY  0', 1160), ('GERMANY  1', 1247), ('GERMANY  2', 1218), ('GERMANY  3', 1214), ('GERMANY  4', 1179), ('GERMANY  5', 1204), ('GERMANY  6', 1165), ('GERMANY  7', 1203), ('GERMANY  8', 1114), ('GERMANY  9', 1268), ('INDIA    0', 1223), ('INDIA    1', 1220), ('INDIA    2', 1224), ('INDIA    3', 1187), ('INDIA    4', 1249), ('INDIA    5', 1207), ('INDIA    6', 1260), ('INDIA    7', 1169), ('INDIA    8', 1209), ('INDIA    9', 1203), ('INDONESIA0', 1232), ('INDONESIA1', 1206), ('INDONESIA2', 1201), ('INDONESIA3', 1208), ('INDONESIA4', 1223), ('INDONESIA5', 1237), ('INDONESIA6', 1265), ('INDONESIA7', 1196), ('INDONESIA8', 1256), ('INDONESIA9', 1264), ('IRAN     0', 1179), ('IRAN     1', 1160), ('IRAN     2', 1222), ('IRAN     3', 1239), ('IRAN     4', 1222), ('IRAN     5', 1198), ('IRAN     6', 1146), ('IRAN     7', 1246), ('IRAN     8', 1224), ('IRAN     9', 1223), ('IRAQ     0', 1217), ('IRAQ     1', 1227), ('IRAQ     2', 1169), ('IRAQ     3', 1147), ('IRAQ     4', 1198), ('IRAQ     5', 1230), ('IRAQ     6', 1219), ('IRAQ     7', 1241), ('IRAQ     8', 1198), ('IRAQ     9', 1161), ('JAPAN    0', 1145), ('JAPAN    1', 1157), ('JAPAN    2', 1174), ('JAPAN    3', 1200), ('JAPAN    4', 1217), ('JAPAN    5', 1269), ('JAPAN    6', 1215), ('JAPAN    7', 1155), ('JAPAN    8', 1159), ('JAPAN    9', 1234), ('JORDAN   0', 1180), ('JORDAN   1', 1192), ('JORDAN   2', 1184), ('JORDAN   3', 1214), ('JORDAN   4', 1275), ('JORDAN   5', 1155), ('JORDAN   6', 1210), ('JORDAN   7', 1243), ('JORDAN   8', 1166), ('JORDAN   9', 1181), ('KENYA    0', 1215), ('KENYA    1', 1185), ('KENYA    2', 1204), ('KENYA    3', 1135), ('KENYA    4', 1170), ('KENYA    5', 1173), ('KENYA    6', 1173), ('KENYA    7', 1166), ('KENYA    8', 1200), ('KENYA    9', 1209), ('MOROCCO  0', 1154), ('MOROCCO  1', 1177), ('MOROCCO  2', 1199), ('MOROCCO  3', 1166), ('MOROCCO  4', 1158), ('MOROCCO  5', 1232), ('MOROCCO  6', 1203), ('MOROCCO  7', 1177), ('MOROCCO  8', 1187), ('MOROCCO  9', 1217), ('MOZAMBIQU0', 1241), ('MOZAMBIQU1', 1174), ('MOZAMBIQU2', 1177), ('MOZAMBIQU3', 1185), ('MOZAMBIQU4', 1167), ('MOZAMBIQU5', 1174), ('MOZAMBIQU6', 11 ...
# Column --> c_nation
# Collected stats for c_nation: min=ALGERIA, max=VIETNAM, total_count=300000, distinct_count=25, histogram=[('ALGERIA', 11842), ('ARGENTINA', 11922), ('BRAZIL', 12064), ('CANADA', 11962), ('CHINA', 12016), ('EGYPT', 11870), ('ETHIOPIA', 12144), ('FRANCE', 12168), ('GERMANY', 11972), ('INDIA', 12151), ('INDONESIA', 12288), ('IRAN', 12059), ('IRAQ', 12007), ('JAPAN', 11925), ('JORDAN', 12000), ('KENYA', 11830), ('MOROCCO', 11870), ('MOZAMBIQUE', 11897), ('PERU', 11900), ('ROMANIA', 12046), ('RUSSIA', 12091), ('SAUDI ARABIA', 11920), ('UNITED KINGDOM', 11988), ('UNITED STATES', 11913), ('VIETNAM', 12155)]
# Column --> c_region
# Collected stats for c_region: min=AFRICA, max=MIDDLE EAST, total_count=300000, distinct_count=5, histogram=[('AFRICA', 59583), ('AMERICA', 59761), ('ASIA', 60535), ('EUROPE', 60265), ('MIDDLE EAST', 59856)]
# Column --> c_phone
# Collected stats for c_phone: min=10-100-137-6232, max=34-999-851-1652, total_count=300000, distinct_count=299999, histogram=None
# Column --> c_mktsegment
# Collected stats for c_mktsegment: min=AUTOMOBILE, max=MACHINERY, total_count=300000, distinct_count=5, histogram=[('AUTOMOBILE', 59587), ('BUILDING', 60359), ('FURNITURE', 60159), ('HOUSEHOLD', 59922), ('MACHINERY', 59973)]
# {'c_custkey': {'min': 1, 'max': 300000, 'total_count': 300000, 'distinct_count': 300000, 'histogram': None}, 'c_name': {'min': 'Customer#000000001', 'max': 'Customer#000300000', 'total_count': 300000, 'distinct_count': 300000, 'histogram': None}, 'c_address': {'min': '   2Ksa,h', 'max': 'zzyQcZpC50YD', 'total_count': 300000, 'distinct_count': 300000, 'histogram': None}, 'c_city': {'min': 'ALGERIA  0', 'max': 'VIETNAM  9', 'total_count': 300000, 'distinct_count': 250, 'histogram': {'ALGERIA  0': 1161, 'ALGERIA  1': 1181, 'ALGERIA  2': 1173, 'ALGERIA  3': 1225, 'ALGERIA  4': 1191, 'ALGERIA  5': 1208, 'ALGERIA  6': 1176, 'ALGERIA  7': 1187, 'ALGERIA  8': 1154, 'ALGERIA  9': 1186, 'ARGENTINA0': 1229, 'ARGENTINA1': 1155, 'ARGENTINA2': 1218, 'ARGENTINA3': 1203, 'ARGENTINA4': 1166, 'ARGENTINA5': 1205, 'ARGENTINA6': 1166, 'ARGENTINA7': 1190, 'ARGENTINA8': 1221, 'ARGENTINA9': 1169, 'BRAZIL   0': 1158, 'BRAZIL   1': 1215, 'BRAZIL   2': 1251, 'BRAZIL   3': 1133, 'BRAZIL   4': 1218, 'BRAZIL   5': 1241, 'BRAZIL   6': 1262, 'BRAZIL   7': 1185, 'BRAZIL   8': 1173, 'BRAZIL   9': 1228, 'CANADA   0': 1152, 'CANADA   1': 1268, 'CANADA   2': 1154, 'CANADA   3': 1224, 'CANADA   4': 1267, 'CANADA   5': 1138, 'CANADA   6': 1206, 'CANADA   7': 1172, 'CANADA   8': 1240, 'CANADA   9': 1141, 'CHINA    0': 1226, 'CHINA    1': 1152, 'CHINA    2': 1215, 'CHINA    3': 1179, 'CHINA    4': 1178, 'CHINA    5': 1228, 'CHINA    6': 1209, 'CHINA    7': 1191, 'CHINA    8': 1224, 'CHINA    9': 1214, 'EGYPT    0': 1212, 'EGYPT    1': 1175, 'EGYPT    2': 1128, 'EGYPT    3': 1165, 'EGYPT    4': 1181, 'EGYPT    5': 1114, 'EGYPT    6': 1234, 'EGYPT    7': 1220, 'EGYPT    8': 1171, 'EGYPT    9': 1270, 'ETHIOPIA 0': 1218, 'ETHIOPIA 1': 1212, 'ETHIOPIA 2': 1212, 'ETHIOPIA 3': 1177, 'ETHIOPIA 4': 1210, 'ETHIOPIA 5': 1190, 'ET
# %%
table = 'lineorder'
lineorder_stats = collect_stats(table, columns=ssb_schema[table])

print(lineorder_stats)
# Out:
# Collecting stats...
# Table --> lineorder
# Column --> lo_orderkey
# Collected stats for lo_orderkey: min=1, max=60000000, total_count=59986214, distinct_count=15000000, histogram=None
# Column --> lo_linenumber
# Collected stats for lo_linenumber: min=1, max=7, total_count=59986214, distinct_count=7, histogram=[(1, 15000000), (2, 12856079), (3, 10710991), (4, 8569709), (5, 6425628), (6, 4283621), (7, 2140186)]
# Column --> lo_custkey
# Collected stats for lo_custkey: min=1, max=299999, total_count=59986214, distinct_count=200000, histogram=None
# Column --> lo_partkey
# Collected stats for lo_partkey: min=1, max=600000, total_count=59986214, distinct_count=600000, histogram=None
# Column --> lo_suppkey
# Collected stats for lo_suppkey: min=1, max=20000, total_count=59986214, distinct_count=20000, histogram=None
# Column --> lo_orderdate
# Collected stats for lo_orderdate: min=1992-01-01, max=1998-08-02
# Column --> lo_orderpriority
# Collected stats for lo_orderpriority: min=1-URGENT, max=5-LOW, total_count=59986214, distinct_count=5, histogram=[('1-URGENT', 12008321), ('2-HIGH', 12002304), ('3-MEDIUM', 11990511), ('4-NOT SPECIFIED', 11999553), ('5-LOW', 11985525)]
# Column --> lo_shippriority
# Collected stats for lo_shippriority: min=0, max=0, total_count=59986214, distinct_count=1, histogram=[('0', 59986214)]
# Column --> lo_quantity
# Collected stats for lo_quantity: min=1, max=50, total_count=59986214, distinct_count=50, histogram=[(1, 1200225), (2, 1198385), (3, 1200809), (4, 1198276), (5, 1200904), (6, 1198121), (7, 1200039), (8, 1200831), (9, 1198720), (10, 1200356), (11, 1199761), (12, 1197630), (13, 1199319), (14, 1197231), (15, 1198969), (16, 1200435), (17, 1199087), (18, 1202044), (19, 1202109), (20, 1200488), (21, 1200263), (22, 1199960), (23, 1199713), (24, 1199378), (25, 1200276), (26, 1199682), (27, 1199981), (28, 1201242), (29, 1200508), (30, 1198226), (31, 1201387), (32, 1200273), (33, 1199942), (34, 1197379), (35, 1200237), (36, 1199861), (37, 1200216), (38, 1199225), (39, 1199782), (40, 1200391), (41, 1199176), (42, 1198863), (43, 1201206), (44, 1198440), (45, 1199612), (46, 1197921), (47, 1201025), (48, 1197832), (49, 1199505), (50, 1200973)]
# Column --> lo_extendedprice
# Collected stats for lo_extendedprice: min=90098, max=10494950, total_count=59986214, distinct_count=1040572, histogram=None
# Column --> lo_ordtotalprice
# Collected stats for lo_ordtotalprice: min=82354, max=56290557, total_count=59986214, distinct_count=11943894, histogram=None
# Column --> lo_discount
# Collected stats for lo_discount: min=0, max=10, total_count=59986214, distinct_count=11, histogram=[(Decimal('0'), 5452209), (Decimal('1'), 5453001), (Decimal('2'), 5451165), (Decimal('3'), 5454600), (Decimal('4'), 5456072), (Decimal('5'), 5452876), (Decimal('6'), 5454232), (Decimal('7'), 5453077), (Decimal('8'), 5455185), (Decimal('9'), 5452359), (Decimal('10'), 5451438)]
# Column --> lo_revenue
# Collected stats for lo_revenue: min=81179, max=10494850, total_count=59986214, distinct_count=5841774, histogram=None
# Column --> lo_supplycost
# Collected stats for lo_supplycost: min=54058, max=125939, total_count=59986214, distinct_count=14535, histogram=None
# Column --> lo_tax
# Collected stats for lo_tax: min=0, max=8, total_count=59986214, distinct_count=9, histogram=[(Decimal('0'), 6661549), (Decimal('1'), 6662072), (Decimal('2'), 6660374), (Decimal('3'), 6670615), (Decimal('4'), 6668295), (Decimal('5'), 6666007), (Decimal('6'), 6665929), (Decimal('7'), 6665779), (Decimal('8'), 6665594)]
# Column --> lo_commitdate
# Collected stats for lo_commitdate: min=1992-01-31, max=1998-10-31
# Column --> lo_shipmode
# Collected stats for lo_shipmode: min=AIR, max=TRUCK, total_count=59986214, distinct_count=7, histogram=[('AIR', 8568652), ('FOB', 8569349), ('MAIL', 8567069), ('RAIL', 8570229), ('REG AIR', 8569749), ('SHIP', 8572968), ('TRUCK', 8568198)]
# {'lo_orderkey': {'min': 1, 'max': 60000000, 'total_count': 59986214, 'distinct_count': 15000000, 'histogram': None}, 'lo_linenumber': {'min': 1, 'max': 7, 'total_count': 59986214, 'distinct_count': 7, 'histogram': {1: 15000000, 2: 12856079, 3: 10710991, 4: 8569709, 5: 6425628, 6: 4283621, 7: 2140186}}, 'lo_custkey': {'min': 1, 'max': 299999, 'total_count': 59986214, 'distinct_count': 200000, 'histogram': None}, 'lo_partkey': {'min': 1, 'max': 600000, 'total_count': 59986214, 'distinct_count': 600000, 'histogram': None}, 'lo_suppkey': {'min': 1, 'max': 20000, 'total_count': 59986214, 'distinct_count': 20000, 'histogram': None}, 'lo_orderdate': {'min': datetime.date(1992, 1, 1), 'max': datetime.date(1998, 8, 2)}, 'lo_orderpriority': {'min': '1-URGENT', 'max': '5-LOW', 'total_count': 59986214, 'distinct_count': 5, 'histogram': {'1-URGENT': 12008321, '2-HIGH': 12002304, '3-MEDIUM': 11990511, '4-NOT SPECIFIED': 11999553, '5-LOW': 11985525}}, 'lo_shippriority': {'min': '0', 'max': '0', 'total_count': 59986214, 'distinct_count': 1, 'histogram': {'0': 59986214}}, 'lo_quantity': {'min': 1, 'max': 50, 'total_count': 59986214, 'distinct_count': 50, 'histogram': {1: 1200225, 2: 1198385, 3: 1200809, 4: 1198276, 5: 1200904, 6: 1198121, 7: 1200039, 8: 1200831, 9: 1198720, 10: 1200356, 11: 1199761, 12: 1197630, 13: 1199319, 14: 1197231, 15: 1198969, 16: 1200435, 17: 1199087, 18: 1202044, 19: 1202109, 20: 1200488, 21: 1200263, 22: 1199960, 23: 1199713, 24: 1199378, 25: 1200276, 26: 1199682, 27: 1199981, 28: 1201242, 29: 1200508, 30: 1198226, 31: 1201387, 32: 1200273, 33: 1199942, 34: 1197379, 35: 1200237, 36: 1199861, 37: 1200216, 38: 1199225, 39: 1199782, 40: 1200391, 41: 1199176, 42: 1198863, 43: 1201206, 44: 1198440, 45: 1199612, 46: 1197921, 47: 1201025, 48: 1197832, 49: 1199505, 50: 1200973}}, 'lo_extendedprice': {'min': Decimal('90098'), 'max': Decimal('10494950'), 'total_count': 59986214, 'distinct_count': 1040572, 'histogram': None}, 'lo_ordtotalprice': {'min': Decimal('82354'), 'max': Decimal('56290557'), 'total_count': 59986214, 'distinct_count': 11943894, 'histogram': None}, 'lo_discount': {'min': Decimal('0'), 'max': Decimal('10'), 'total_count': 59986214, 'distinct_count': 11, 'histogram': {Decimal('0'): 5452209, Decimal('1'): 5453001, Decimal('2'): 5451165, Decimal('3'): 5454600, Decimal('4'): 5456072, Decimal('5'): 5452876, Decimal('6'): 5454232, Decimal('7'): 5453077, Decimal('8'): 5455185, Decimal('9'): 5452359, Decimal('10'): 5451438}}, 'lo_revenue': {'min': Decimal('81179'), 'max': Decimal('10494850'), 'total_count': 59986214, 'distinct_count': 5841774, 'histogram': None}, 'lo_supplycost': {'min': Decimal('54058'), 'max': Decimal('125939'), 'total_count': 59986214, 'distinct_count': 14535, 'histogram': None}, 'lo_tax': {'min': Decimal('0'), 'max': Decimal('8'), 'total_count': 59986214, 'distinct_count': 9, 'histogram': {Decimal('0'): 6661549, Decimal('1'): 6662072, Decimal('2'): 6660374, Decimal('3'): 6670615, Decimal('4'): 6668295, Decimal('5'): 6666007, Decimal('6'): 6665929, Decimal('7'): 6665779, Decimal('8'): 6665594}}, 'lo_commitdate': {'min': datetime.date(1992, 1, 31), 'max': datetime.date(1998, 10, 31)}, 'lo_shipmode': {'min': 'AIR', 'max': 'TRUCK', 'total_count': 59986214, 'distinct_count': 7, 'histogram': {'AIR': 8568652, 'FOB': 8569349, 'MAIL': 8567069, 'RAIL': 8570229, 'REG AIR': 8569749, 'SHIP': 8572968, 'TRUCK': 8568198}}}

# %%
table = 'part'
part_stats = collect_stats(table, columns=ssb_schema[table])

print(part_stats)
# Out:
# Collecting stats...
# Table --> part
# Column --> p_partkey
# Collected stats for p_partkey: min=1, max=800000, total_count=800000, distinct_count=800000, histogram=None
# Column --> p_name
# Collected stats for p_name: min=almond antique, max=yellow white, total_count=800000, distinct_count=8372, histogram=None
# Column --> p_mfgr
# Collected stats for p_mfgr: min=MFGR#1, max=MFGR#5, total_count=800000, distinct_count=5, histogram=[('MFGR#1', 160027), ('MFGR#2', 159744), ('MFGR#3', 160085), ('MFGR#4', 159933), ('MFGR#5', 160211)]
# Column --> p_category
# Collected stats for p_category: min=MFGR#11, max=MFGR#55, total_count=800000, distinct_count=25, histogram=[('MFGR#11', 31934), ('MFGR#12', 31882), ('MFGR#13', 32100), ('MFGR#14', 31901), ('MFGR#15', 32210), ('MFGR#21', 31757), ('MFGR#22', 31939), ('MFGR#23', 32265), ('MFGR#24', 32029), ('MFGR#25', 31754), ('MFGR#31', 31908), ('MFGR#32', 32065), ('MFGR#33', 31934), ('MFGR#34', 31984), ('MFGR#35', 32194), ('MFGR#41', 32323), ('MFGR#42', 31967), ('MFGR#43', 32060), ('MFGR#44', 31895), ('MFGR#45', 31688), ('MFGR#51', 32068), ('MFGR#52', 31611), ('MFGR#53', 32337), ('MFGR#54', 32187), ('MFGR#55', 32008)]
# Column --> p_brand
# Collected stats for p_brand: min=MFGR#111, max=MFGR#559, total_count=800000, distinct_count=1000, histogram=[('MFGR#111', 729), ('MFGR#1110', 834), ('MFGR#1111', 818), ('MFGR#1112', 762), ('MFGR#1113', 838), ('MFGR#1114', 791), ('MFGR#1115', 783), ('MFGR#1116', 815), ('MFGR#1117', 824), ('MFGR#1118', 784), ('MFGR#1119', 774), ('MFGR#112', 771), ('MFGR#1120', 769), ('MFGR#1121', 802), ('MFGR#1122', 787), ('MFGR#1123', 796), ('MFGR#1124', 813), ('MFGR#1125', 821), ('MFGR#1126', 831), ('MFGR#1127', 778), ('MFGR#1128', 774), ('MFGR#1129', 787), ('MFGR#113', 814), ('MFGR#1130', 809), ('MFGR#1131', 815), ('MFGR#1132', 838), ('MFGR#1133', 731), ('MFGR#1134', 832), ('MFGR#1135', 799), ('MFGR#1136', 815), ('MFGR#1137', 767), ('MFGR#1138', 816), ('MFGR#1139', 796), ('MFGR#114', 772), ('MFGR#1140', 778), ('MFGR#115', 815), ('MFGR#116', 806), ('MFGR#117', 798), ('MFGR#118', 813), ('MFGR#119', 839), ('MFGR#121', 769), ('MFGR#1210', 806), ('MFGR#1211', 810), ('MFGR#1212', 773), ('MFGR#1213', 813), ('MFGR#1214', 822), ('MFGR#1215', 795), ('MFGR#1216', 852), ('MFGR#1217', 824), ('MFGR#1218', 801), ('MFGR#1219', 769), ('MFGR#122', 815), ('MFGR#1220', 763), ('MFGR#1221', 806), ('MFGR#1222', 801), ('MFGR#1223', 754), ('MFGR#1224', 832), ('MFGR#1225', 796), ('MFGR#1226', 839), ('MFGR#1227', 778), ('MFGR#1228', 835), ('MFGR#1229', 769), ('MFGR#123', 819), ('MFGR#1230', 759), ('MFGR#1231', 805), ('MFGR#1232', 862), ('MFGR#1233', 777), ('MFGR#1234', 801), ('MFGR#1235', 817), ('MFGR#1236', 819), ('MFGR#1237', 824), ('MFGR#1238', 717), ('MFGR#1239', 790), ('MFGR#124', 779), ('MFGR#1240', 826), ('MFGR#125', 771), ('MFGR#126', 769), ('MFGR#127', 791), ('MFGR#128', 791), ('MFGR#129', 743), ('MFGR#131', 795), ('MFGR#1310', 805), ('MFGR#1311', 811), ('MFGR#1312', 807), ('MFGR#1313', 890), ('MFGR#1314', 821), ('MFGR#1315', 868), ('MFGR#1316', 880), ('MFGR#1317', 811), ('MFGR#1318', 799), ('MFGR#1319', 818), ('MFGR#132', 795), ('MFGR#1320', 810), ('MFGR#1321', 836), ('MFGR#1322', 753), ('MFGR#1323', 748), ('MFGR#1324', 821), ('MFGR#1325', 784), ('MFGR#1326', 818), ('MFGR#1327', 798), ('MFGR#1328', 787), ('MFGR#1329', 794), ('MFGR#133', 850), ('MFGR#1330', 762), ('MFGR#1331', 827), ('MFGR#1332', 772), ('MFGR#1333', 756), ('MFGR#1334', 812), ('MFGR#1335', 791), ('MFGR#1336', 782), ('MFGR#1337', 800), ('MFGR#1338', 779
# Column --> p_size
# Collected stats for p_size: min=1, max=50, total_count=800000, distinct_count=50, histogram=[(1, 15940), (2, 15832), (3, 16177), (4, 16174), (5, 15939), (6, 16069), (7, 16039), (8, 15818), (9, 16034), (10, 16245), (11, 16005), (12, 15881), (13, 15981), (14, 16123), (15, 15995), (16, 16176), (17, 16043), (18, 15776), (19, 15745), (20, 15866), (21, 16083), (22, 16096), (23, 15950), (24, 16288), (25, 15787), (26, 15990), (27, 16053), (28, 15972), (29, 15997), (30, 15992), (31, 15707), (32, 15977), (33, 16073), (34, 16185), (35, 16284), (36, 15817), (37, 15869), (38, 16440), (39, 16079), (40, 15924), (41, 15975), (42, 15908), (43, 15809), (44, 16133), (45, 15902), (46, 15889), (47, 15980), (48, 16234), (49, 15884), (50, 15865)]
# Column --> p_container
# Collected stats for p_container: min=JUMBO BAG, max=WRAP PKG, total_count=800000, distinct_count=40, histogram=[('JUMBO BAG', 20119), ('JUMBO BOX', 20073), ('JUMBO CAN', 20315), ('JUMBO CASE', 19823), ('JUMBO DRUM', 19886), ('JUMBO JAR', 20305), ('JUMBO PACK', 20005), ('JUMBO PKG', 19906), ('LG BAG', 19698), ('LG BOX', 20085), ('LG CAN', 19780), ('LG CASE', 19867), ('LG DRUM', 19947), ('LG JAR', 20086), ('LG PACK', 20148), ('LG PKG', 20050), ('MED BAG', 20110), ('MED BOX', 20041), ('MED CAN', 19825), ('MED CASE', 20142), ('MED DRUM', 19882), ('MED JAR', 20001), ('MED PACK', 20025), ('MED PKG', 20141), ('SM BAG', 20030), ('SM BOX', 19896), ('SM CAN', 19793), ('SM CASE', 19767), ('SM DRUM', 20382), ('SM JAR', 19869), ('SM PACK', 20111), ('SM PKG', 19960), ('WRAP BAG', 19959), ('WRAP BOX', 20047), ('WRAP CAN', 19989), ('WRAP CASE', 19969), ('WRAP DRUM', 20027), ('WRAP JAR', 20097), ('WRAP PACK', 19857), ('WRAP PKG', 19987)]
# {'p_partkey': {'min': 1, 'max': 800000, 'total_count': 800000, 'distinct_count': 800000, 'histogram': None}, 'p_name': {'min': 'almond antique', 'max': 'yellow white', 'total_count': 800000, 'distinct_count': 8372, 'histogram': None}, 'p_mfgr': {'min': 'MFGR#1', 'max': 'MFGR#5', 'total_count': 800000, 'distinct_count': 5, 'histogram': {'MFGR#1': 160027, 'MFGR#2': 159744, 'MFGR#3': 160085, 'MFGR#4': 159933, 'MFGR#5': 160211}}, 'p_category': {'min': 'MFGR#11', 'max': 'MFGR#55', 'total_count': 800000, 'distinct_count': 25, 'histogram': {'MFGR#11': 31934, 'MFGR#12': 31882, 'MFGR#13': 32100, 'MFGR#14': 31901, 'MFGR#15': 32210, 'MFGR#21': 31757, 'MFGR#22': 31939, 'MFGR#23': 32265, 'MFGR#24': 32029, 'MFGR#25': 31754, 'MFGR#31': 31908, 'MFGR#32': 32065, 'M
FGR#1329': 794, 'MFGR#133': 850, 'MFGR#1330': 762, 'MFGR#1331': 827, 'MFGR#1332': 772, 'MFGR#1333': 756, 'MFGR#1334': 812, 'MFGR#1335': 791, 'MFGR#1336': 782, 'MFGR#1337': 800, 'MFGR#1338': 779, 'MFGR#1339': 755, 'MFGR#134': 800, 'MFGR#1340': 821, 'MFGR#135': 770, 'MFGR#136': 810, 'MFGR#137': 781, 'MFGR#138': 809, 'MFGR#139': 774, 'MFGR#141': 818, 'MFGR#1410': 823, 'MFGR#1411': 806, 'MFGR#1412': 794, 'MFGR#1413': 793, 'MFGR#1414': 821, 'MFGR#1415': 765, 'MFGR#1416': 798, 'MFGR#1417': 826, 'MFGR#1418': 746, 'MFGR#1419': 810, 'MFGR#142': 784, 'MFGR#1420': 835, 'MFGR#1421': 808, 'MFGR#1422': 789, 'MFGR#1423': 771, 'MFGR#1424': 811, 'MFGR#1425': 798, 'MFGR#1426': 801, 'MFGR#1427': 798, 'MFGR#1428': 772, 'MFGR#1429': 773, 'MFGR#143': 792, 'MFGR#1430': 842, 'MFGR#1431': 822, 'MFGR#1432': 778, 'MFGR#1433': 817, 'MFGR#1434': 818, 'MFGR#1435': 795, 'MFGR#1436': 778, 'MFGR#1437': 810, 'MFGR#1438': 780, 'MFGR#1439': 770, 'MFGR#144': 793, 'MFGR#1440': 784, 'MFGR#145': 808, 'MFGR#146': 821, 'MFGR#147': 739, 'MFGR#148': 842, 'MFGR#149': 772, 'MFGR#151': 840, 'MFGR#1510': 806, 'MFGR#1511': 819,  ...

# %%
table = 'supplier'
supplier_stats = collect_stats(table, columns=ssb_schema[table])

print(supplier_stats)
# Out:
# Collecting stats...
# Table --> supplier
# Column --> s_suppkey
# Collected stats for s_suppkey: min=1, max=20000, total_count=20000, distinct_count=20000, histogram=None
# Column --> s_name
# Collected stats for s_name: min=Supplier#000000001       , max=Supplier#000020000       , total_count=20000, distinct_count=20000, histogram=None
# Column --> s_address
# Collected stats for s_address: min=  3TLxhVMg, max=zzl8o8MHkQAs, total_count=20000, distinct_count=20000, histogram=None
# Column --> s_city
# Collected stats for s_city: min=ALGERIA  0, max=VIETNAM  9, total_count=20000, distinct_count=250, histogram=[('ALGERIA  0', 70), ('ALGERIA  1', 91), ('ALGERIA  2', 86), ('ALGERIA  3', 67), ('ALGERIA  4', 68), ('ALGERIA  5', 98), ('ALGERIA  6', 80), ('ALGERIA  7', 66), ('ALGERIA  8', 71), ('ALGERIA  9', 90), ('ARGENTINA0', 87), ('ARGENTINA1', 92), ('ARGENTINA2', 84), ('ARGENTINA3', 79), ('ARGENTINA4', 76), ('ARGENTINA5', 86), ('ARGENTINA6', 77), ('ARGENTINA7', 102), ('ARGENTINA8', 76), ('ARGENTINA9', 89), ('BRAZIL   0', 93), ('BRAZIL   1', 75), ('BRAZIL   2', 81), ('BRAZIL   3', 71), ('BRAZIL   4', 79), ('BRAZIL   5', 76), ('BRAZIL   6', 82), ('BRAZIL   7', 83), ('BRAZIL   8', 77), ('BRAZIL   9', 80), ('CANADA   0', 67), ('CANADA   1', 73), ('CANADA   2', 95), ('CANADA   3', 90), ('CANADA   4', 91), ('CANADA   5', 90), ('CANADA   6', 81), ('CANADA   7', 70), ('CANADA   8', 76), ('CANADA   9', 85), ('CHINA    0', 60), ('CHINA    1', 67), ('CHINA    2', 82), ('CHINA    3', 91), ('CHINA    4', 104), ('CHINA    5', 74), ('CHINA    6', 80), ('CHINA    7', 70), ('CHINA    8', 76), ('CHINA    9', 89), ('EGYPT    0', 83), ('EGYPT    1', 70), ('EGYPT    2', 94), ('EGYPT    3', 65), ('EGYPT    4', 69), ('EGYPT    5', 79), ('EGYPT    6', 91), ('EGYPT    7', 79), ('EGYPT    8', 87), ('EGYPT    9', 83), ('ETHIOPIA 0', 76), ('ETHIOPIA 1', 79), ('ETHIOPIA 2', 64), ('ETHIOPIA 3', 75), ('ETHIOPIA 4', 86), ('ETHIOPIA 5', 82), ('ETHIOPIA 6', 81), ('ETHIOPIA 7', 73), ('ETHIOPIA 8', 69), ('ETHIOPIA 9', 60), ('FRANCE   0', 89), ('FRANCE   1', 58), ('FRANCE   2', 89), ('FRANCE   3', 79), ('FRANCE   4', 78), ('FRANCE   5', 80), ('FRANCE   6', 79), ('FRANCE   7', 85), ('FRANCE   8', 74), ('FRANCE   9', 64), ('GERMANY  0', 87), ('GERMANY  1', 71), ('GERMANY  2', 78), ('GERMANY  3', 75), ('GERMANY  4', 71), ('GERMANY  5', 84), ('GERMANY  6', 83), ('GERMANY  7', 85), ('GERMANY  8', 93), ('GERMANY  9', 77), ('INDIA    0', 70), ('INDIA    1', 79), ('INDIA    2', 69), ('INDIA    3', 63), ('INDIA    4', 84), ('INDIA    5', 98), ('INDIA    6', 97), ('INDIA    7', 90), ('INDIA    8', 85), ('INDIA    9', 74), ('INDONESIA0', 100), ('INDONESIA1', 72), ('INDONESIA2', 85), ('INDONESIA3', 85), ('INDONESIA4', 73), ('INDONESIA5', 98), ('INDONESIA6', 87), ('INDONESIA7', 90), ('INDONESIA8', 76), ('INDONESIA9', 76), ('IRAN     0', 76), ('IRAN     1', 74), ('IRAN     2', 80), ('IRAN     3', 83), ('IRAN     4', 77), ('IRAN     5', 92), ('IRAN     6', 69), ('IRAN     7', 101), ('IRAN     8', 83), ('IRAN     9', 76), ('IRAQ     0', 64), ('IRAQ     1', 86), ('IRAQ     2', 83), ('IRAQ     3', 77), ('IRAQ     4', 91), ('IRAQ     5', 90), ('IRAQ     6', 84), ('IRAQ     7', 95), ('IRAQ     8', 92), ('IRAQ     9', 85), ('JAPAN    0', 75), ('JAPAN    1', 82), ('JAPAN    2', 91), ('JAPAN    3', 74), ('JAPAN    4', 73), ('JAPAN    5', 76), ('JAPAN    6', 77), ('JAPAN    7', 84), ('JAPAN    8', 80), ('JAPAN    9', 83), ('JORDAN   0', 76), ('JORDAN   1', 74), ('JORDAN   2', 91), ('JORDAN   3', 81), ('JORDAN   4', 81), ('JORDAN   5', 73), ('JORDAN   6', 73), ('JORDAN   7', 81), ('JORDAN   8', 89), ('JORDAN   9', 87), ('KENYA    0', 77), ('KENYA    1', 65), ('KENYA    2', 89), ('KENYA    3', 77), ('KENYA    4', 91), ('KENYA    5', 69), ('KENYA    6', 69), ('KENYA    7', 67), ('KENYA    8', 69), ('KENYA    9', 64), ('MOROCCO  0', 75), ('MOROCCO  1', 53), ('MOROCCO  2', 71), ('MOROCCO  3', 90), ('MOROCCO  4', 74), ('MOROCCO  5', 91), ('MOROCCO  6', 75), ('MOROCCO  7', 77), ('MOROCCO  8', 69), ('MOROCCO  9', 85), ('MOZAMBIQU0', 85), ('MOZAMBIQU1', 82), ('MOZAMBIQU2', 79), ('MOZAMBIQU3', 72), ('MOZAMBIQU4', 87), ('MOZAMBIQU5', 79), ('MOZAMBIQU6', 76), ('MOZAMBIQU7', 87), ('MOZAMBIQU8', 73), ('MOZAMBIQU9', 92), ('PERU     0', 76), ('PERU     1', 87), ('PERU     2', 74), ('PERU     3', 103), ('PERU     4', 92), ('PERU     5', 77), ('PERU     6', 82), ('PERU     7', 83), ('PERU     8', 69), ('PERU     9', 87), ('ROMANIA  0', 67), ('ROMANIA  1', 71), ('ROMANIA  2', 67), ('ROMANIA  3', 96), ('ROM ...
# Column --> s_nation
# Collected stats for s_nation: min=ALGERIA, max=VIETNAM, total_count=20000, distinct_count=25, histogram=[('ALGERIA', 787), ('ARGENTINA', 848), ('BRAZIL', 797), ('CANADA', 818), ('CHINA', 793), ('EGYPT', 800), ('ETHIOPIA', 745), ('FRANCE', 775), ('GERMANY', 804), ('INDIA', 809), ('INDONESIA', 842), ('IRAN', 811), ('IRAQ', 847), ('JAPAN', 795), ('JORDAN', 806), ('KENYA', 737), ('MOROCCO', 760), ('MOZAMBIQUE', 812), ('PERU', 830), ('ROMANIA', 774), ('RUSSIA', 826), ('SAUDI ARABIA', 820), ('UNITED KINGDOM', 793), ('UNITED STATES', 809), ('VIETNAM', 762)]
# Column --> s_region
# Collected stats for s_region: min=AFRICA, max=MIDDLE EAST, total_count=20000, distinct_count=5, histogram=[('AFRICA', 3841), ('AMERICA', 4102), ('ASIA', 4001), ('EUROPE', 3972), ('MIDDLE EAST', 4084)]
# Column --> s_phone
# Collected stats for s_phone: min=10-100-600-9363, max=34-999-411-6738, total_count=20000, distinct_count=20000, histogram=None
# {'s_suppkey': {'min': 1, 'max': 20000, 'total_count': 20000, 'distinct_count': 20000, 'histogram': None}, 's_name': {'min': 'Supplier#000000001       ', 'max': 'Supplier#000020000       ', 'total_count': 20000, 'distinct_count': 20000, 'histogram': None}, 's_address': {'min': '  3TLxhVMg', 'max': 'zzl8o8MHkQAs', 'total_count': 20000, 'distinct_count': 20000, 'histogram': None}, 's_city': {'min': 'ALGERIA  0', 'max': 'VIETNAM  9', 'total_count': 20000, 'distinct_count': 250, 'histogram': {'ALGERIA  0': 70, 'ALGERIA  1': 91, 'ALGERIA  2': 86, 'ALGERIA  3': 67, 'ALGERIA  4': 68, 'ALGERIA  5': 98, 'AL
     2': 83, 'IRAQ     3': 77, 'IRAQ     4': 91, 'IRAQ     5': 90, 'IRAQ     6': 84, 'IRAQ     7': 95, 'IRAQ     8': 92, 'IRAQ     9': 85, 'JAPAN    0': 75, 'JAPAN    1': 82, 'JAPAN    2': 91, 'JAPAN    3': 74, 'JAPAN    4': 73, 'JAPAN    5': 76, 'JAPAN    6': 77, 'JAPAN    7': 84, 'JAPAN    8': 80, 'JAPAN    9': 83, 'JORDAN   0': 76, 'JORDAN   1': 74, 'JORDAN   2': 91, 'JORDAN   3': 81, 'JORDAN   4': 81, 'JORDAN   5': 73, 'JORDAN   6': 73, 'JORDAN   7': 81, 'JORDAN   8': 89, 'JORDAN   9': 87, 'KENYA    0': 77, 'KENYA    1': 65, 'KENYA    2': 89, 'KENYA    3': 77, 'KENYA    4': 91, 'KENYA    5': 69, 'KENYA    6': 69, 'KENYA    7': 67, 'KENYA    8': 69, 'KENYA    9': 64, 'MOROCCO  0': 75, 'MOROCCO  1': 53, 'MOROCCO  2': 71, 'MOROCCO  3': 90, 'MOROCCO  4': 74, 'MOROCCO  5': 91, 'MOROCCO  6': 75, 'MOROCCO  7': 77, 'MOROCCO  8': 69, 'MOROCCO  9': 85, 'MOZAMBIQU0': 85, 'MOZAMBIQU1': 82, 'MOZAMBIQU2': 79, 'MOZAMBIQU3': 72, 'MOZAMBIQU4': 87, 'MOZAMBIQU5': 79, 'MOZAMBIQU6': 76, 'MOZAMBIQU7': 87, 'MOZAMBIQU8': 73, 'MOZAMBIQU9': 92, 'PERU     0': 76, 'PERU     1': 87, 'PERU     2': 74, 'PERU     3': 103, 'PERU     4': 92, 'PERU     5': 77, 'PERU     6': 82, 'PERU     7': 83, 'PERU     8': 69, 'PERU     9': 87, 'ROMANIA  0': 67, 'ROMANIA  1': 71, 'ROMANIA  2': 67, 'ROMANIA  3': 96, 'ROMANIA   ...

# %%
table = 'dwdate'
dwdate_stats = collect_stats(table, columns=ssb_schema[table])

print(dwdate_stats)
# Out:
# Collecting stats...
# Table --> dwdate
# Column --> d_datekey
# Collected stats for d_datekey: min=1992-01-01, max=1998-12-30
# Column --> d_date
# Collected stats for d_date: min=April 1, 1992, max=September 9, 1998, total_count=2556, distinct_count=2556, histogram=None
# Column --> d_dayofweek
# Collected stats for d_dayofweek: min=Friday, max=Wednesday, total_count=2556, distinct_count=7, histogram=[('Friday', 365), ('Monday', 365), ('Saturday', 365), ('Sunday', 365), ('Thursday', 366), ('Tuesday', 365), ('Wednesday', 365)]
# Column --> d_month
# Collected stats for d_month: min=April, max=September, total_count=2556, distinct_count=12, histogram=[('April', 210), ('Augest', 217), ('December', 216), ('February', 198), ('January', 217), ('July', 217), ('June', 210), ('March', 217), ('May', 217), ('November', 210), ('Octorber', 217), ('September', 210)]
# Column --> d_year
# Collected stats for d_year: min=1992, max=1998, total_count=2556, distinct_count=7, histogram=[(1992, 366), (1993, 365), (1994, 365), (1995, 365), (1996, 366), (1997, 365), (1998, 364)]
# Column --> d_yearmonthnum
# Column --> d_sellingseason
# Collected stats for d_sellingseason: min=Christmas, max=Winter, total_count=2556, distinct_count=5, histogram=[('Christmas', 426), ('Fall', 427), ('Spring', 210), ('Summer', 861), ('Winter', 632)]
# Column --> d_lastdayinweekfl
# Column --> d_lastdayinmonthfl
# Column --> d_holidayfl
# Column --> d_weekdayfl
# {'d_datekey': {'min': datetime.date(1992, 1, 1), 'max': datetime.date(1998, 12, 30)}, 'd_date': {'min': 'April 1, 1992', 'max': 'September 9, 1998', 'total_count': 2556, 'distinct_count': 2556, 'histogram': None}, 'd_dayofweek': {'min': 'Friday', 'max': 'Wednesday', 'total_count': 2556, 'distinct_count': 7, 'histogram': {'Friday': 365, 'Monday': 365, 'Saturday': 365, 'Sunday': 365, 'Thursday': 366, 'Tuesday': 365, 'Wednesday': 365}}, 'd_month': {'min': 'April', 'max': 'September', 'total_count': 2556, 'distinct_count': 12, 'histogram': {'April': 210, 'Augest': 217, 'December': 216, 'February': 198, 'January': 217, 'July': 217, 'June': 210, 'March': 217, 'May': 217, 'November': 210, 'Octorber': 217, 'September': 210}}, 'd_year': {'min': 1992, 'max': 1998, 'total_count': 2556, 'distinct_count': 7, 'histogram': {1992: 366, 1993: 365, 1994: 365, 1995: 365, 1996: 366, 1997: 365, 1998: 364}}, 'd_yearmonthnum': {'min': 199201, 'max': 199812, 'total_count': 2556, 'distinct_count': 84, 'histogram': {199201: 31, 199202: 29, 199203: 31, 199204: 30, 199205: 31, 199206: 30, 199207: 31, 199208: 31, 199209: 30, 199210: 31, 199211: 30, 199212: 31, 199301: 31, 199302: 28, 199303: 31, 199304: 30, 199305: 31, 199306: 30, 199307: 31, 199308: 31, 199309: 30, 199310: 31, 199311: 30, 199312: 31, 199401: 31, 199402: 28, 199403: 31, 199404: 30, 199405: 31, 199406: 30, 199407: 31, 199408: 31, 199409: 30, 199410: 31, 199411: 30, 199412: 31, 199501: 31, 199502: 28, 199503: 31, 199504: 30, 199505: 31, 199506: 30, 199507: 31, 199508: 31, 199509: 30, 199510: 31, 199511: 30, 199512: 31, 199601: 31, 199602: 29, 199603: 31, 199604: 30, 199605: 31, 199606: 30, 199607: 31, 199608: 31, 199609: 30, 199610: 31, 199611: 30, 199612: 31, 199701: 31, 199702: 28, 199703: 31, 199704: 30, 199705: 31, 199706: 30, 199707: 31, 199708: 31, 199709: 30, 199710: 31, 199711: 30, 199712: 31, 199801: 31, 199802: 28, 199803: 31, 199804: 30, 199805: 31, 199806: 30, 199807: 31, 199808: 31, 199809: 30, 199810: 31, 199811: 30, 199812: 30}}, 'd_yearmonth': {'min': 'Apr1992', 'max': 'Sep1998', 'total_count': 2556, 'distinct_count': 84, 'histogram': {'Apr1992': 30, 'Apr1993': 30, 'Apr1994': 30, 'Apr1995': 30, 'Apr1996': 30, 'Apr1997': 30, 'Apr1998': 30, 'Aug1992': 31, 'Aug1993': 31, 'Aug1994': 31, 'Aug1995': 31, 'Aug1996': 31, 'Aug1997': 31, 'Aug1998': 31, 'Dec1992': 31, 'Dec1993': 31, 'Dec1994': 31, 'Dec1995': 31, 'Dec1996': 31, 'Dec1997': 31, 'Dec1998': 30, 'Feb1992': 29, 'Feb1993': 28, 'Feb1994': 28, 'Feb1995': 28, 'Feb1996': 29, 'Feb1997': 28, 'Feb1998': 28, 'Jan1992': 31, 'Jan1993': 31, 'Jan1994': 31, 'Jan1995': 31, 'Jan1996': 31, 'Jan1997': 31, 'Jan1998': 31, 'Jul1992': 31, 'Jul1993': 31, 'Jul1994': 31, 'Jul1995': 31, 'Jul1996': 31, 'Jul1997': 31, 'Jul1998': 31, 'Jun1992': 30, 'Jun1993': 30, 'Jun1994': 30, 'Jun1995': 30, 'Jun1996': 30, 'Jun1997': 30, 'Jun1998': 30, 'Mar1992': 31, 'Mar1993': 31, 'Mar1994': 31, 'Mar1995': 31, 'Mar1996': 31, 'Mar1997': 31, 'Mar1998': 31, 'May1992': 31, 'May1993': 31, 'May1994': 31, 'May1995': 31, 'May1996': 31, 'May1997': 31, 'May1998': 31, 'Nov1992': 30, 'Nov1993': 30, 'Nov1994': 30, 'Nov1995': 30, 'Nov1996': 30, 'Nov1997': 30, 'Nov1998': 30, 'Oct1992': 31, 'Oct1993': 31, 'Oct1994': 31, 'Oct1995': 31, 'Oct1996': 31, 'Oct1997': 31, 'Oct1998': 31, 'Sep1992': 30, 'Sep1993': 30, 'Sep1994': 30, 'Sep1995': 30, 'Sep1996': 30, 'Sep1997': 30, 'Sep1998': 30}}, 'd_daynuminweek': {'min': 1, 'max': 7, 'total_count': 2556, 'distinct_count': 7, 'histogram': {1: 365, 2: 365, 3: 365, 4: 365, 5: 366, 6: 365, 7: 365}}, 'd_daynuminmonth': {'min': 1, 'max': 31, 'total_count': 2556, 'distinct_count': 31, 'histogram': {1: 84, 2: 84, 3: 84, 4: 84, 5: 84, 6: 84, 7: 84, 8: 84, 9: 84, 10: 84, 11: 84, 12: 84, 13: 84, 14: 84, 15: 84, 16: 84, 17: 84, 18: 84, 19: 84, 20: 84, 21: 84, 22: 84, 23: 84, 24: 84, 25: 84, 26: 84, 27: 84, 28: 84, 29: 79, 30: 77, 31: 48}}, 'd_daynuminyear': {'min': 1, 'max': 366, 'total_count': 2556, 'distinct_count': 366, 'histogram': {1: 7, 2: 7, 3: 7, 4: 7 ...

# %%
# create an ssb stats dictionary
ssb_stats = {
    "customer": customer_stats,
    "lineorder": lineorder_stats,
    "part": part_stats,
    "supplier": supplier_stats,
    "dwdate": dwdate_stats
}

# save ssb schema and ssb stats to pickle files
import pickle

with open('ssb_schema.pkl', 'wb') as f:
    pickle.dump(ssb_schema, f)

with open('ssb_stats.pkl', 'wb') as f:  
    pickle.dump(ssb_stats, f)
